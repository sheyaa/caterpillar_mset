# %% [markdown]
# ## Importing Libraries

# %%
# Data Processing
import numpy as np
import pandas as pd
from collections import Counter

# Importing tde
import tde

# Visualization
import matplotlib.pyplot as plt

# To generate the for loops
import glob
import os
from matplotlib import ticker

# %% [markdown]
# ## Reading Mice Data

# %%
# Get the data
folder = "/Users/yoddmena/Downloads/Research/Telemetry_edited/"

files = glob.glob( folder + "Ex *.xlsx" ) 

minutes = []
temp = []

#k = 0
for file in files:
    #k = k +1
    #if k > 2:
        #break
    df = pd.read_excel(file) # reading the excel file
    
    file_min = df.iloc[:,0] #getting only the minutes
    file_temp = df.iloc[:,3::2] # slicing the data for only temperature
    
    minutes.append(file_min) # adding minutes into the list
    temp.append(file_temp) # adding the file into the list

# %% [markdown]
# ## Plotting Each Time Series with its Mean

# %%
fig,ax = plt.subplots(figsize=(15,4))
fig.set_facecolor("white") # Changing the border to white
mean = []


# Plotting each file's temperature vs. minutes
for i in range(len(minutes)):
    mouse_min = minutes[i] # renaming the minutes to the current column
    mouse_temp = temp[i] # renaming the temperature to the current column
    x_axis = mouse_min # defining the x axis
    
    # A for loop for the temperatures (extracting only the column of data frame)
    for j in range(mouse_temp.shape[1]): 
        ax.clear() # clear axis for each individual mouse
        y_axis = mouse_temp.iloc[:,j] # defining the y axis
        names = mouse_temp.columns[j] # extracting the names of the columns (mouse name)
        
        # Filling in missing values using forward fill
        y1_fw = y_axis.fillna(method='ffill')
        y1_bw = y1_fw.fillna(method='bfill') #backward fill
        
        # Calculating the mean
        mean_value = np.mean(y1_bw)
        mean.append(mean_value)
        
        # Plotting the time series
        ax.plot(x_axis, y_axis, label=names) # plotting the time series
        ax.grid(True) # adding a grid
        ax.set_xlim(-500,25000,2000)
        ax.set_ylim(30,42,0.5)
        ax.set_xlabel("Minutes") #x label
        ax.set_ylabel('Temperature (°C)') #y label
        ax.legend() # name of the mouse
        suffix = str(i).zfill(4)

        # Add a horizontal line for the mean value
        plt.axhline(mean_value, color='r', linestyle='-', label='Mean')
        
        # Saving the Image
        #filename = "Mean_Inter/%s.png"%names # saving the file as the name of the mouse
        #fig.savefig(filename)

# %% [markdown]
# ## Calculating the Means

# %%
mean_values = []  # List to store mean values
mouse_names = []  # List to store mouse names

# Calculating the mean for each mouse's time series
for i in range(len(minutes)):
    mice_min = minutes[i]  # Renaming the minutes to the current column
    mice_temp = temp[i]  # Renaming the temperature to the current column
    x_axis = mice_min  # Defining the x axis

    # A for loop for the temperatures (extracting only the column of data frame)
    for j in range(mice_temp.shape[1]):
        y_axis = mice_temp.iloc[:, j]  # Defining the y axis
        mouse_name = mice_temp.columns[j]  # Extracting the name of the column (mouse name)
        
        # Filling in missing values using forward fill
        y1_fw = y_axis.fillna(method='ffill')
        y1_bw = y1_fw.fillna(method='bfill') #backward fill

        # Calculating the mean
        mean_value = y_axis.mean()

        # Appending the mean and mouse name to the lists
        mean_values.append(mean_value)
        mouse_names.append(mouse_name)

# Creating a DataFrame from the mean values and mouse names
df_means = pd.DataFrame({'Mouse': mouse_names, 'Mean': mean_values})

# Filter the DataFrame for a specific mouse name
specific_mouse = 'B6-102 EXP. 3 MRSA Deg. C Data'  # Replace 'Mouse1' with the desired mouse name
filtered_df = df_means.loc[df_means['Mouse'] == specific_mouse]

# %%
# Uncomment to see all the means
df_means

# %%
filtered_df

# %%
mean_hist_int = plt.hist(mean_values, bins=15, color='#C64B8C', edgecolor='black')
# Set the y-axis limit
plt.grid(True, linestyle='--', linewidth=0.5, color='gray', alpha=0.5)
plt.ylim(0,45)
plt.xlim(34,39)


# Adding x and y labels
plt.xlabel('Mean')
plt.ylabel('Frequency')
plt.title('Means After Interpolation') 

# Saving the Image
filename1 = "Means_Inter_histogram.png"   # saving the file as the name of the mouse
plt.savefig(filename1, facecolor='white')

# %%
histogram, bin_edges = np.histogram(mean_values, bins=15)  

# Create a DataFrame from the histogram data
df_histogram_int = pd.DataFrame({'Mean': bin_edges[:-1], 'Frequency': histogram})

# Create a table visualization using matplotlib
fig, ax = plt.subplots(figsize=(6, 4))
ax.axis('off')
table = ax.table(cellText=df_histogram_int.values, colLabels=df_histogram_int.columns, rowLabels=df_histogram_int.index, loc='center')
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1, 2)  # Adjust the scaling factor as per your requirements

# Modify the column names as dark color boxes
for i, col_name in enumerate(df_histogram_int.columns):
    cell = table[0, i]
    cell.set_text_props(weight='bold', color='white')
    cell.set_facecolor('darkgray')
    
# Print the resulting DataFrame
#print(df_histogram)

# Save the table as an image file
plt.savefig('mean_int_freq_table.png', bbox_inches='tight', facecolor='white')
