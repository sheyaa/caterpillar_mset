# %% [markdown]
# # One Class Support Vector Machines

# %% [markdown]
# ## Importing Libraries

# %%
# Data Processing
import numpy as np
import pandas as pd
from collections import Counter

# Importing tde
import tde

import matplotlib.pyplot as plt

# Model and Performance
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.svm import OneClassSVM
from sklearn.metrics import classification_report #for model performance evaluation

# To generate the for loops
import glob
import os
from matplotlib import ticker

# %% [markdown]
# ## Data Management

# %%
# READ INFECTION TIME DATA
infection_data = pd.read_excel('/Users/yoddmena/Downloads/Research/Telemetry_edited/MRSA - Master sheet.xlsx', index_col=0)

# READ AND EXTRACT DATA FROM FOLDER CONTAINING EXCEL SHEETS
folder = "/Users/yoddmena/Downloads/Research/Telemetry_edited/"
files = glob.glob( folder + "Ex *.xlsx" )

# %%
# CREATE A LIST OF TEMPERATURES
temp = []

for file in files:
    df = pd.read_excel(file)
    file_temp = df.iloc[:, 3::2]  # slicing the data for only temperature
    
    # Ensure that the number of minutes matches the number of temperature columns
    num_temp_columns = file_temp.shape[1]
    
    # Iterate over every other column in file_temp
    for j in range(0, num_temp_columns):
        # Extract the specific temperature column and its corresponding minutes
        column_name = file_temp.columns[j]
        temperature = file_temp[column_name]
        
        # Append the temperature and minutes to each lists
        temp.append(temperature)

# %% [markdown]
# ## Creating Data Frames

# %%
##### INFECTION DATA
infection_data = infection_data.iloc[:,[1,9]]
infection_data = infection_data.T # transpose the data

infection_data.columns = infection_data.iloc[0] # Assign the values of the first row as the new column names

infection_data = infection_data[1:] # Remove the first row (previous column names)


##### TEMPERATURE DATA
df_temp = pd.DataFrame(temp)
df_temp = df_temp.T # transpose the data

df_temp.columns = df_temp.columns.astype(str).str.split(' ').str[0] # Rename columns keeping only the first word

# %% [markdown]
# ## Scores

# %%
# IMPORTING THE SVM MODEL
# this model is from SckiKit Learn
model = svm.OneClassSVM()

# SIGMOID DEFINITION
# we will use the sigmoid function to make our scores be a numerical value that lies between 0 and 1

beta = (2/700) # 700 is the largest value
def sigmoid(scores, beta):
    return 1 / (1 + np.exp(-beta * scores))

# %%
#fig,ax = plt.subplots(2,1,figsize=(15,10), sharex = False)
#fig.set_facecolor("white")

train_end = 4320
shift = 2*360 # since the period is 6 hours (360) and we do this twice

# LISTS
# First anomalies after infection
min_scores = []
first_anom_train = []
first_anom_inf = []
score_train = []
score_infec = []
tpr = []

for i in range(0, df_temp.shape[1]): #df_temp.shape[1]
    #ax[0].cla()  # clear axis 0-1
    #ax[1].cla()
    
    #mice_min = range(0, df_temp.shape[0]) # Get the specific minutes for the current temperature time series
    
    temp_value = df_temp.iloc[:, i] # extract the temperature values for the current column
    mice_temp = df_temp.iloc[:, i].to_frame() # converting temp list to data frame
    
    names = mice_temp.columns[0] # get the column name for the current file
    
    # Filing in missing data
    temp_value_fw = temp_value.fillna(method='ffill') # foward fill
    temp_value_bw = temp_value_fw.fillna(method='bfill') # backward fill after forward fill
    
    # Time Delay Embedding
    temp_tde = tde.tde(temp_value_bw) # using the tde file
    temp_tde = temp_tde.T # transporting the data
    
    ##################################################################
    # Fit the Data on the first 3 days (3*24*60) 
    model.fit(temp_tde[:train_end+1,:])
    
    # Predict the Data
    predict_train_data = model.predict(temp_tde[:train_end+1,:]) # predict on training data
    predict_test_data = model.predict(temp_tde[train_end+1:,:]) # predicting on test data
    
    # Scores
    scores_train_data = model.score_samples(temp_tde[:train_end+1,:]) # scores on training data 
    scores_test_data = model.score_samples(temp_tde[train_end+1:,:]) # scores on test data
    
    threshold = model.offset_
    
    ##################################################################
    # Combine training and testing scores and predictions
    combined_scores= np.concatenate((scores_train_data, scores_test_data), axis=0)
    combined_predictions = np.concatenate((predict_train_data, predict_test_data), axis=0)
    
    time = np.arange(temp_tde.shape[0])+(shift) # 2 times the time delay shift
    
    # Minimum score
    min_score = scores_train_data.min()
    
    # Find the indices of the anomalies
    anomaly_indices = np.where(combined_scores <= min_score)[0] #finding the values where its -1 (anomaly)
    time_2 = anomaly_indices + (shift) # shifting the time for plotting
    '''
    ##################################################################
    # Plotting 1st Graph
    ax[0].plot(time, combined_scores, '-', color='#6693F5', alpha=0.75)  # Plot the scores with blue color #[:100]
    ax[0].grid()
    ax[0].set_ylabel("Score", fontsize=14)
    ax[0].set_title(f"Anomalies found using SckiKit Learn's threshold for '{names}'", fontsize=14)
    ax[0].set_xlim(-10,26000)
    ax[0].set_ylim(0,700)
    ax[0].axhline(y = threshold, color='red', linestyle='-', label='threshold')
    # Plot the anomalies with red color
    #ax[0].plot(time_2, combined_scores[anomaly_indices], '', color='purple') #[:100]
    #ax[0].axhline(y=min_score, color='red', linestyle='-')
    '''
    ##################################################################
    # Plotting infection time
    matching_columns = set(mice_temp.columns).intersection(infection_data.columns)
    
    if matching_columns:
        column_name = matching_columns.pop()
        infection_time = infection_data.loc['Aprprox Infection Minute', column_name]
        # Add a vertical line at the infection time
        #ax[1].axvline(x = infection_time, color='purple', linestyle='-', label='Infection time')
        print(f"Found '{column_name}' and its infection value is '{infection_time}'")
    else:
        print(f"No match found for mouse '{names}'")
    
    ##################################################################
    # Find the index at which the first score is less than min_score
    boolean = combined_scores < min_score
    anom_train = np.argmax(boolean) #+shift
    anom_infec = np.argmax(boolean[infection_time-shift:]) + infection_time 
    
    # Get the corresponding value
    value = combined_scores[anom_train]
    value_1 = combined_scores[anom_infec-shift]
    
    # Calculating the time first anomaly was found after training and infection
    time_aft_train = (anom_train + shift) - train_end
    time_aft_infection = anom_infec - infection_time
    
    # Calculating the amount of false negatives (between end of train and infection time)
    count_false_neg = np.count_nonzero(boolean[train_end:infection_time])
    
    # Calculating the amount of true positives (infection time)
    count_true_pos = np.count_nonzero(boolean[infection_time:]) 
    
    # Calculating true positive rate
    # Check if the denominator is zero
    if (count_true_pos + count_false_neg) == 0:
        print("Skipping division ")
        continue  # Skip this iteration and move to the next number
    TPR = count_true_pos / (count_true_pos + count_false_neg)
    '''
    ##################################################################
    # Plotting 2nd Graph
    ax[1].plot(time, combined_scores, '-', color='#6693F5', alpha=0.75)  # Plot the scores with blue color #[:100]
    ax[1].plot(time_2, combined_scores[anomaly_indices], '', color='purple') #coloring anomalies
    ax[1].grid()
    ax[1].set_ylabel("Score", fontsize=14)
    ax[1].set_xlabel("Minutes", fontsize=14)
    ax[1].set_title(f"Anomalies found using our threshold for '{names}'", fontsize=14)
    #ax[1].set_xlim(infection_time-5,infection_time+30)
    ax[1].set_xlim(-10,26000)
    ax[1].set_ylim(0,700)
    
    ##################################################################
    # Plotting Horizontal and Vertical Lines
    ax[1].axvline(x = anom_train+shift, color='blue', linestyle='--', label='First anomaly after training') # when the first value is less the minimum value
    ax[1].axvline(x = train_end, color='green', linestyle='-', label='End of training data')
    ax[1].axhline(y=min_score, color='red', linestyle='-', label='Threshold')
    ax[1].axvline(x = anom_infec, color='orange', linestyle ='-', label='First anomaly after infection')
    #ax[1].axhline(y=value, color='blue', linestyle='--', label='value')
    #ax[1].axhline(y=value_1, color='orange', linestyle='-', label='value_1')
    ax[1].legend()
    '''
    ##################################################################
    # Print Values
    print("Minimum Score: ", min_score)
    print("After Training Min: ", anom_train+shift)
    print("After Infection Min: ", anom_infec)
    print(f"First anomaly found after training: {time_aft_train} minutes with score {value}")
    print(f"First anomaly found after infection: {time_aft_infection} minutes with score {value_1}")
    print(f"True Positve Rate: {TPR*100}%")
    
    ##################################################################
    # Appending to Lists
    min_scores.append(min_score)
    first_anom_train.append(time_aft_train)
    first_anom_inf.append(time_aft_infection)
    score_train.append(value)
    score_infec.append(value_1)
    tpr.append(TPR)
# Out:
# Found 'CC006-315' and its infection value is '10300'
# Minimum Score:  267.52007264767286
# After Training Min:  11043
# After Infection Min:  11043
# First anomaly found after training: 6723 minutes with score 267.4976407369712
# First anomaly found after infection: 743 minutes with score 267.4976407369712
# True Positve Rate: 100.0%
# Found 'CC006-316' and its infection value is '10300'
# Minimum Score:  274.82851288077353
# After Training Min:  6949
# After Infection Min:  10462
# First anomaly found after training: 2629 minutes with score 271.684894294429
# First anomaly found after infection: 162 minutes with score 268.1715669032109
# True Positve Rate: 98.08883112911857%
# Found 'CC006-317' and its infection value is '10300'
# Minimum Score:  293.83288135042164
# After Training Min:  6702
# After Infection Min:  12666
# First anomaly found after training: 2382 minutes with score 271.149233897299
# First anomaly found after infection: 2366 minutes with score 263.58820191686965
# True Positve Rate: 99.80148455031936%
# Found 'CC019-1392' and its infection value is '10300'
# Minimum Score:  212.29037014244363
# After Training Min:  7511
# After Infection Min:  10319
# First anomaly found after training: 3191 minutes with score 209.78823280158565
# First anomaly found after infection: 19 minutes with score 178.39535055887603
# True Positve Rate: 93.7125748502994%
# No match found for mouse 'CC019-1393'
# Minimum Score:  201.40131604221705
# After Training Min:  7146
# After Infection Min:  11040
# First anomaly found after training: 2826 minutes with score 117.59936356268173
# First anomaly found after infection: 740 minutes with score 169.22919236755138
# True Positve Rate: 98.77018817602607%
# Found 'CC043-455' and its infection value is '10300'
# Skipping division
# Found 'CC043-456' and its infection value is '10300'
# Minimum Score:  220.4569600410759
# After Training Min:  6735
# After Infection Min:  12113
# First anomaly found after training: 2415 minutes with score 215.61355404465144
# First anomaly found after infection: 1813 minutes with score 193.74451174154655
# True Positve Rate: 94.83385884065001%
# Found 'CC043-457' and its infection value is '10300'
# Skipping division
# Found 'CC051-489' and its infection value is '10300'
# Minimum Score:  238.9300181242933
# After Training Min:  6113
# After Infection Min:  10340
# First anomaly found after training: 1793 minutes with score 212.66205249227568
# First anomaly found after infection: 40 minutes with score 223.71671150963306
# True Positve Rate: 89.6328293736501%
# Found 'CC051-490' and its infection value is '10300'
# Minimum Score:  215.330698492076
# After Training Min:  6122
# After Infection Min:  10705
# First anomaly found after training: 1802 minutes with score 203.8736485200348
# First anomaly found after infection: 405 minutes with score 193.4477675496525
# True Positve Rate: 99.26747178776479%
# Found 'CC057-610' and its infection value is '10300'
# Minimum Score:  200.84077753916517
# After Training Min:  7034
# After Infection Min:  12811
# First anomaly found after training: 2714 minutes with score 196.64466726013643
# First anomaly found after infection: 2511 minutes with score 189.36779218356503
# True Positve Rate: 99.52936142902983%
# Found 'CC002-607' and its infection value is '11250'
# Minimum Score:  97.80512594093989
# After Training Min:  6198
# After Infection Min:  14435
# First anomaly found after training: 1878 minutes with score 93.53687077894034
# First anomaly found after infection: 3185 minutes with score 91.47061768941609
# True Positve Rate: 69.6078431372549%
# Found 'CC002-609' and its infection value is '11250'
# Minimum Score:  177.56524083948625
# After Training Min:  10742
# After Infection Min:  11471
# First anomaly found after training: 6422 minutes with score 174.5737318741099
# First anomaly found after infection: 221 minutes with score 175.55968135526234
# True Positve Rate: 97.41541353383458%
# Found 'CC002-610' and its infection value is '11250'
# Minimum Score:  186.45145706278555
# After Training Min:  5186
# After Infection Min:  11261
# First anomaly found after training: 866 minutes with score 178.84250167406566
# First anomaly found after infection: 11 minutes with score 143.78325465288532
# True Positve Rate: 93.62542309138774%
# Found 'CC003-178' and its infection value is '11250'
# Minimum Score:  319.4026227352844
# After Training Min:  5141
# After Infection Min:  11273
# First anomaly found after training: 821 minutes with score 317.27505432011606
# First anomaly found after infection: 23 minutes with score 295.8851824132265
# True Positve Rate: 99.46505804689278%
# Found 'CC003-179' and its infection value is '11250'
# Minimum Score:  239.14555898873255
# After Training Min:  5791
# After Infection Min:  11275
# First anomaly found after training: 1471 minutes with score 217.62450711176334
# First anomaly found after infection: 25 minutes with score 205.88852279796453
# True Positve Rate: 83.1896551724138%
# Found 'CC003-180' and its infection value is '11250'
# Minimum Score:  229.20471042009228
# After Training Min:  11284
# After Infection Min:  11284
# First anomaly found after training: 6964 minutes with score 207.01381080982088
# First anomaly found after infection: 34 minutes with score 207.01381080982088
# True Positve Rate: 50.0%
# Found 'CC005-433' and its infection value is '11250'
# Minimum Score:  311.34595649359363
# After Training Min:  5669
# After Infection Min:  11283
# First anomaly found after training: 1349 minutes with score 310.84951177942247
# First anomaly found after infection: 33 minutes with score 235.07805452380455
# True Positve Rate: 87.5%
# Found 'CC005-434' and its infection value is '11250'
# Minimum Score:  272.73784284600475
# After Training Min:  6324
# After Infection Min:  11285
# First anomaly found after training: 2004 minutes with score 270.3154051054518
# First anomaly found after infection: 35 minutes with score 266.9145999442724
# True Positve Rate: 99.75436328377505%
# Found 'CC005-435' and its infection value is '11250'
# Minimum Score:  313.92807550387613
# After Training Min:  6326
# After Infection Min:  11290
# First anomaly found after training: 2006 minutes with score 311.09021102875744
# First anomaly found after infection: 40 minutes with score 152.32958160783278
# True Positve Rate: 23.943661971830984%
# No match found for mouse 'CC011-564'
# Minimum Score:  229.63105027162436
# After Training Min:  8165
# After Infection Min:  11287
# First anomaly found after training: 3845 minutes with score 227.59216893161914
# First anomaly found after infection: 37 minutes with score 148.77661268553692
# True Positve Rate: 97.1045197740113%
# No match found for mouse 'CC011-565'
# Minimum Score:  305.5002361383008
# After Training Min:  7210
# After Infection Min:  11306
# First anomaly found after training: 2890 minutes with score 302.8722153618927
# First anomaly found after infection: 56 minutes with score 303.55208865733476
# True Positve Rate: 91.49507609668755%
# No match found for mouse 'CC011-566'
# Minimum Score:  204.43768126784164
# After Training Min:  11314
# After Infection Min:  11314
# First anomaly found after training: 6994 minutes with score 196.58562459086954
# First anomaly found after infection: 64 minutes with score 196.58562459086954
# True Positve Rate: 66.0%
# Found 'CC013-642' and its infection value is '11250'
# Minimum Score:  216.65128781371916
# After Training Min:  8198
# After Infection Min:  11421
# First anomaly found after training: 3878 minutes with score 216.20468719919722
# First anomaly found after infection: 171 minutes with score 211.7715625208132
# True Positve Rate: 90.47619047619048%
# Found 'CC013-643' and its infection value is '11250'
# Minimum Score:  287.5610891923437
# After Training Min:  7389
# After Infection Min:  11286
# First anomaly found after training: 3069 minutes with score 285.9590144538758
# First anomaly found after infection: 36 minutes with score 282.76045134127367
# True Positve Rate: 65.66479877738156%
# Found 'CC013-644' and its infection value is '11250'
# Minimum Score:  298.3719316398323
# After Training Min:  8645
# After Infection Min:  11486
# First anomaly found after training: 4325 minutes with score 207.9885275428063
# First anomaly found after infection: 236 minutes with score 297.5817100619849
# True Positve Rate: 97.01960784313725%
# No match found for mouse 'B6-103'
# Minimum Score:  308.32537446796744
# After Training Min:  5214
# After Infection Min:  11275
# First anomaly found after training: 894 minutes with score 284.0223541916539
# First anomaly found after infection: 25 minutes with score 306.85230287250886
# True Positve Rate: 96.29230437594309%
# Found 'CC001-364' and its infection value is '10250'
# Minimum Score:  217.33935950764163
# After Training Min:  5921
# After Infection Min:  10251
# First anomaly found after training: 1601 minutes with score 216.81097093242886
# First anomaly found after infection: 1 minutes with score 204.98942870336646
# True Positve Rate: 3.3333333333333335%
# Found 'CC001-366' and its infection value is '10250'
# Minimum Score:  228.22563959151606
# After Training Min:  5267
# After Infection Min:  12382
# First anomaly found after training: 947 minutes with score 210.6300858538827
# First anomaly found after infection: 2132 minutes with score 214.56811397150102
# True Positve Rate: 51.183431952662716%
# Found 'CC003-225' and its infection value is '10250'
# Minimum Score:  232.67180713933914
# After Training Min:  10997
# After Infection Min:  10997
# First anomaly found after training: 6677 minutes with score 203.1991567801985
# First anomaly found after infection: 747 minutes with score 203.1991567801985
# True Positve Rate: 100.0%
# Found 'CC017-455' and its infection value is '10250'
# Minimum Score:  195.0703291824148
# After Training Min:  5526
# After Infection Min:  10398
# First anomaly found after training: 1206 minutes with score 191.05782289532164
# First anomaly found after infection: 148 minutes with score 182.76450851669108
# True Positve Rate: 68.6382393397524%
# Found 'CC017-456' and its infection value is '10250'
# Skipping division
# Found 'CC036-299' and its infection value is '10250'
# Minimum Score:  323.19474810136023
# After Training Min:  5303
# After Infection Min:  10337
# First anomaly found after training: 983 minutes with score 304.426578995666
# First anomaly found after infection: 87 minutes with score 311.3600906587017
# True Positve Rate: 97.50237663123326%
# No match found for mouse 'B6-100'
# Minimum Score:  254.51716861905857
# After Training Min:  14191
# After Infection Min:  14191
# First anomaly found after training: 9871 minutes with score 191.4869720334907
# First anomaly found after infection: 3941 minutes with score 191.4869720334907
# True Positve Rate: 100.0%
# No match found for mouse 'B6-101'
# Minimum Score:  270.6397383182709
# After Training Min:  16312
# After Infection Min:  16312
# First anomaly found after training: 11992 minutes with score 265.4585726959036
# First anomaly found after infection: 6062 minutes with score 265.4585726959036
# True Positve Rate: 100.0%
# Found 'CC002-557' and its infection value is '14200'
# Minimum Score:  154.95117991187385
# After Training Min:  16166
# After Infection Min:  16166
# First anomaly found after training: 11846 minutes with score 148.2246177425813
# First anomaly found after infection: 1966 minutes with score 148.2246177425813
# True Positve Rate: 100.0%
# Found 'CC002-558' and its infection value is '14200'
# Minimum Score:  210.74568174220337
# After Training Min:  6397
# After Infection Min:  14559
# First anomaly found after training: 2077 minutes with score 206.70493572999246
# First anomaly found after infection: 359 minutes with score 208.71848401046552
# True Positve Rate: 97.42647058823529%
# Found 'CC002-559' and its infection value is '14200'
# Minimum Score:  125.18433123514222
# After Training Min:  5102
# After Infection Min:  14220
# First anomaly found after training: 782 minutes with score 115.76899734306176
# First anomaly found after infection: 20 minutes with score 106.77889704078945
# True Positve Rate: 0.5412156536219818%
# Found 'CC015-390' and its infection value is '14200'
# Minimum Score:  219.09887442237078
# After Training Min:  5239
# After Infection Min:  14229
# First anomaly found after training: 919 minutes with score 205.5957205724822
# First anomaly found after infection: 29 minutes with score 217.37242569812344
# True Positve Rate: 49.22737306843267%
# Found 'CC015-391' and its infection value is '14200'
# Minimum Score:  175.35939042906494
# After Training Min:  19593
# After Infection Min:  19593
# First anomaly found after training: 15273 minutes with score 166.01679387717286
# First anomaly found after infection: 5393 minutes with score 166.01679387717286
# True Positve Rate: 100.0%
# Found 'CC015-392' and its infection value is '14200'
# Minimum Score:  329.86817093794554
# After Training Min:  6714
# After Infection Min:  15602
# First anomaly found after training: 2394 minutes with score 318.59564704641934
# First anomaly found after infection: 1402 minutes with score 321.69549378368924
# True Positve Rate: 6.704707560627675%
# Found 'CC038-582' and its infection value is '14200'
# Minimum Score:  214.60836933611887
# After Training Min:  8256
# After Infection Min:  14241
# First anomaly found after training: 3936 minutes with score 206.98844904654976
# First anomaly found after infection: 41 minutes with score 167.5885312268145
# True Positve Rate: 89.57133717210493%
# Found 'CC038-583' and its infection value is '14200'
# Minimum Score:  210.09413610539477
# After Training Min:  5330
# After Infection Min:  14244
# First anomaly found after training: 1010 minutes with score 207.18648079968472
# First anomaly found after infection: 44 minutes with score 168.05315301247896
# True Positve Rate: 62.69185360094451%
# Found 'CC051-495' and its infection value is '14200'
# Minimum Score:  219.2706058329397
# After Training Min:  8444
# After Infection Min:  14390
# First anomaly found after training: 4124 minutes with score 209.2003682472937
# First anomaly found after infection: 190 minutes with score 207.9072563095455
# True Positve Rate: 80.14646053702197%
# Found 'CC051-496' and its infection value is '14200'
# Minimum Score:  270.22326866489936
# After Training Min:  5123
# After Infection Min:  14200
# First anomaly found after training: 803 minutes with score 242.91220950341764
# First anomaly found after infection: 0 minutes with score 189.60947594535622
# True Positve Rate: 65.99845797995374%
# Found 'CC006-507' and its infection value is '10500'
# Minimum Score:  255.67960166921347
# After Training Min:  9924
# After Infection Min:  11390
# First anomaly found after training: 5604 minutes with score 252.9321885559889
# First anomaly found after infection: 890 minutes with score 248.656882684803
# True Positve Rate: 98.80749574105621%
# Found 'CC006-508' and its infection value is '10500'
# Minimum Score:  298.73218521798907
# After Training Min:  13020
# After Infection Min:  13020
# First anomaly found after training: 8700 minutes with score 294.1293449427099
# First anomaly found after infection: 2520 minutes with score 294.1293449427099
# True Positve Rate: 100.0%
# Found 'CC017-413' and its infection value is '10500'
# Minimum Score:  182.27979630414126
# After Training Min:  20028
# After Infection Min:  20028
# First anomaly found after training: 15708 minutes with score 181.61191823390493
# First anomaly found after infection: 9528 minutes with score 181.61191823390493
# True Positve Rate: 100.0%
# Found 'CC036-276' and its infection value is '10500'
# Minimum Score:  333.29704568063676
# After Training Min:  10498
# After Infection Min:  10500
# First anomaly found after training: 6178 minutes with score 307.0458679991405
# First anomaly found after infection: 0 minutes with score 245.1334847241559
# True Positve Rate: 99.76492712740949%
# Found 'CC036-279' and its infection value is '10500'
# Minimum Score:  238.42607710273978
# After Training Min:  6542
# After Infection Min:  10504
# First anomaly found after training: 2222 minutes with score 230.3377068207585
# First anomaly found after infection: 4 minutes with score 197.36755302433625
# True Positve Rate: 97.93294270833334%
# No match found for mouse 'CC036-280'
# Minimum Score:  205.5766121189447
# After Training Min:  13513
# After Infection Min:  13513
# First anomaly found after training: 9193 minutes with score 205.4922915150645
# First anomaly found after infection: 3013 minutes with score 205.4922915150645
# True Positve Rate: 100.0%
# Found 'CC036-281' and its infection value is '10500'
# Minimum Score:  313.4698801181623
# After Training Min:  6881
# After Infection Min:  10506
# First anomaly found after training: 2561 minutes with score 313.4557473503711
# First anomaly found after infection: 6 minutes with score 309.34665545285316
# True Positve Rate: 99.52655590944306%
# Found 'CC057-732' and its infection value is '10500'
# Minimum Score:  228.33970627995745
# After Training Min:  9247
# After Infection Min:  12801
# First anomaly found after training: 4927 minutes with score 221.42738938381478
# First anomaly found after infection: 2301 minutes with score 225.92206723711325
# True Positve Rate: 98.60302677532013%
# Found 'CC061-554' and its infection value is '10500'
# Minimum Score:  270.1155743014992
# After Training Min:  5058
# After Infection Min:  10519
# First anomaly found after training: 738 minutes with score 269.8129545391105
# First anomaly found after infection: 19 minutes with score 237.00638964081503
# True Positve Rate: 17.894736842105264%
# Found 'CC061-555' and its infection value is '10500'
# Minimum Score:  254.32371350378915
# After Training Min:  6963
# After Infection Min:  10518
# First anomaly found after training: 2643 minutes with score 252.21014655491933
# First anomaly found after infection: 18 minutes with score 241.5342331838244
# True Positve Rate: 4.358353510895883%
# Found 'CC061-556' and its infection value is '10500'
# Minimum Score:  250.67817127460677
# After Training Min:  5440
# After Infection Min:  10520
# First anomaly found after training: 1120 minutes with score 245.17969738695575
# First anomaly found after infection: 20 minutes with score 200.75366388933185
# True Positve Rate: 99.44762089349743%
# Found 'B6-117' and its infection value is '10500'
# Minimum Score:  218.92888334683278
# After Training Min:  10524
# After Infection Min:  10524
# First anomaly found after training: 6204 minutes with score 162.94256610866717
# First anomaly found after infection: 24 minutes with score 162.94256610866717
# True Positve Rate: 34.21052631578947%
# Found 'CC001-304' and its infection value is '11300'
# Minimum Score:  224.9223073361121
# After Training Min:  6825
# After Infection Min:  12999
# First anomaly found after training: 2505 minutes with score 221.02225408544234
# First anomaly found after infection: 1699 minutes with score 219.64568137419067
# True Positve Rate: 99.72306143001008%
# No match found for mouse 'CC001-306'
# Minimum Score:  297.3829145117937
# After Training Min:  5246
# After Infection Min:  11300
# First anomaly found after training: 926 minutes with score 296.8309070298099
# First anomaly found after infection: 0 minutes with score 143.12071081374768
# True Positve Rate: 96.75513900921477%
# Found 'CC013-671' and its infection value is '11300'
# Minimum Score:  255.64158590802242
# After Training Min:  7568
# After Infection Min:  12469
# First anomaly found after training: 3248 minutes with score 223.28345954202166
# First anomaly found after infection: 1169 minutes with score 240.88631527786413
# True Positve Rate: 99.8481067592492%
# Found 'CC013-672' and its infection value is '11300'
# Minimum Score:  256.87083979617154
# After Training Min:  13735
# After Infection Min:  13735
# First anomaly found after training: 9415 minutes with score 254.30563710000266
# First anomaly found after infection: 2435 minutes with score 254.30563710000266
# True Positve Rate: 100.0%
# Found 'CC013-673' and its infection value is '11300'
# Minimum Score:  333.5919668398689
# After Training Min:  6832
# After Infection Min:  11685
# First anomaly found after training: 2512 minutes with score 312.2647421124288
# First anomaly found after infection: 385 minutes with score 323.8356306061857
# True Positve Rate: 99.51941560938101%
# Found 'CC015-439' and its infection value is '11300'
# Minimum Score:  228.4739392338593
# After Training Min:  7557
# After Infection Min:  12292
# First anomaly found after training: 3237 minutes with score 226.13107028656316
# First anomaly found after infection: 992 minutes with score 224.0733796833532
# True Positve Rate: 99.96301433194638%
# No match found for mouse 'CC015-442'
# Minimum Score:  327.00360998950686
# After Training Min:  6833
# After Infection Min:  11372
# First anomaly found after training: 2513 minutes with score 325.8583722736405
# First anomaly found after infection: 72 minutes with score 326.0629842816213
# True Positve Rate: 82.37671786580437%
# No match found for mouse 'CC024-361'
# Minimum Score:  311.95269867368694
# After Training Min:  6840
# After Infection Min:  11317
# First anomaly found after training: 2520 minutes with score 302.25226047631065
# First anomaly found after infection: 17 minutes with score 309.15963482166205
# True Positve Rate: 99.54433609769434%
# Found 'CC024-362' and its infection value is '11300'
# Minimum Score:  233.35887601663097
# After Training Min:  6849
# After Infection Min:  11329
# First anomaly found after training: 2529 minutes with score 230.18101256304516
# First anomaly found after infection: 29 minutes with score 224.53654405944997
# True Positve Rate: 56.71641791044776%
# Found 'CC025-598' and its infection value is '11300'
# Minimum Score:  269.3658282976675
# After Training Min:  6712
# After Infection Min:  15432
# First anomaly found after training: 2392 minutes with score 263.4185055269716
# First anomaly found after infection: 4132 minutes with score 266.3256292911952
# True Positve Rate: 7.291666666666667%
# Found 'CC025-599' and its infection value is '11300'
# Minimum Score:  280.07306865278036
# After Training Min:  6712
# After Infection Min:  11338
# First anomaly found after training: 2392 minutes with score 259.2872104702783
# First anomaly found after infection: 38 minutes with score 235.17889289690083
# True Positve Rate: 77.06422018348624%
# Found 'CC025-600' and its infection value is '11300'
# Minimum Score:  309.0099539688994
# After Training Min:  5244
# After Infection Min:  11347
# First anomaly found after training: 924 minutes with score 295.44111155871764
# First anomaly found after infection: 47 minutes with score 287.59491502538657
# True Positve Rate: 74.1248097412481%
# Found 'CC038-659' and its infection value is '11300'
# Minimum Score:  181.54902132749885
# After Training Min:  6320
# After Infection Min:  11345
# First anomaly found after training: 2000 minutes with score 175.42011966223453
# First anomaly found after infection: 45 minutes with score 144.72643866889752
# True Positve Rate: 99.16611074049366%
# Found 'CC038-660' and its infection value is '11300'
# Minimum Score:  277.5758821426835
# After Training Min:  5156
# After Infection Min:  11348
# First anomaly found after training: 836 minutes with score 275.0412947158141
# First anomaly found after infection: 48 minutes with score 255.2483036365113
# True Positve Rate: 22.29580573951435%
# Found 'CC038-661' and its infection value is '11300'
# Minimum Score:  237.89813250325375
# After Training Min:  5327
# After Infection Min:  11353
# First anomaly found after training: 1007 minutes with score 235.0153323999604
# First anomaly found after infection: 53 minutes with score 210.18755537525334
# True Positve Rate: 87.5%
# Found 'CC015-514' and its infection value is '11500'
# Minimum Score:  229.56519175964922
# After Training Min:  6864
# After Infection Min:  16679
# First anomaly found after training: 2544 minutes with score 217.28862567779748
# First anomaly found after infection: 5179 minutes with score 212.19497383172825
# True Positve Rate: 99.77381251570746%
# Found 'CC015-515' and its infection value is '11500'
# Minimum Score:  230.14003512345704
# After Training Min:  6853
# After Infection Min:  12842
# First anomaly found after training: 2533 minutes with score 165.06147941787646
# First anomaly found after infection: 1342 minutes with score 209.26683773142662
# True Positve Rate: 90.08810572687224%
# Found 'CC024-409' and its infection value is '11500'
# Minimum Score:  282.09563518775667
# After Training Min:  6862
# After Infection Min:  11500
# First anomaly found after training: 2542 minutes with score 281.22401067045035
# First anomaly found after infection: 0 minutes with score 264.8983727663347
# True Positve Rate: 68.72037914691943%
# No match found for mouse 'CC036-271'
# Minimum Score:  357.37570013435294
# After Training Min:  5712
# After Infection Min:  11559
# First anomaly found after training: 1392 minutes with score 346.09396374061487
# First anomaly found after infection: 59 minutes with score 341.09832124511854
# True Positve Rate: 94.17048414623193%
# Found 'CC036-272' and its infection value is '11500'
# Minimum Score:  267.8139182616715
# After Training Min:  5346
# After Infection Min:  12464
# First anomaly found after training: 1026 minutes with score 247.8206597586135
# First anomaly found after infection: 964 minutes with score 263.4104418001229
# True Positve Rate: 99.71163748712667%
# Found 'CC053-426' and its infection value is '11500'
# Minimum Score:  197.92527793139118
# After Training Min:  6918
# After Infection Min:  11500
# First anomaly found after training: 2598 minutes with score 197.84132101932744
# First anomaly found after infection: 0 minutes with score 553.5518062577883
# True Positve Rate: 0.0%
# Found 'CC053-427' and its infection value is '11500'
# Minimum Score:  210.56980102256637
# After Training Min:  5446
# After Infection Min:  11868
# First anomaly found after training: 1126 minutes with score 195.83775427051341
# First anomaly found after infection: 368 minutes with score 202.10065806361763
# True Positve Rate: 97.13406424312367%
# Found 'CC053-428' and its infection value is '11500'
# Minimum Score:  250.15654007967382
# After Training Min:  5304
# After Infection Min:  11500
# First anomaly found after training: 984 minutes with score 229.81109105751773
# First anomaly found after infection: 0 minutes with score 148.46087898657242
# True Positve Rate: 57.474069554606466%
# Found 'CC057-730' and its infection value is '11500'
# Minimum Score:  245.03481439094543
# After Training Min:  8507
# After Infection Min:  11743
# First anomaly found after training: 4187 minutes with score 237.27755846227703
# First anomaly found after infection: 243 minutes with score 242.1530816226212
# True Positve Rate: 17.97752808988764%
# Found 'CC057-731' and its infection value is '11500'
# Minimum Score:  242.46492146687655
# After Training Min:  9319
# After Infection Min:  11674
# First anomaly found after training: 4999 minutes with score 241.47453455797591
# First anomaly found after infection: 174 minutes with score 233.09722801340894
# True Positve Rate: 98.78853540825372%
# Found 'CC058-296' and its infection value is '11500'
# Minimum Score:  158.05503559787326
# After Training Min:  12644
# After Infection Min:  12644
# First anomaly found after training: 8324 minutes with score 152.70069289865796
# First anomaly found after infection: 1144 minutes with score 152.70069289865796
# True Positve Rate: 100.0%
# Found 'CC058-297' and its infection value is '11500'
# Minimum Score:  187.37156261403578
# After Training Min:  6876
# After Infection Min:  11893
# First anomaly found after training: 2556 minutes with score 176.0563814475284
# First anomaly found after infection: 393 minutes with score 181.54179183741246
# True Positve Rate: 98.91402714932127%
# Found 'CC058-298' and its infection value is '11500'
# Minimum Score:  208.85905075132496
# After Training Min:  7597
# After Infection Min:  11899
# First anomaly found after training: 3277 minutes with score 202.3586974098357
# First anomaly found after infection: 399 minutes with score 206.78358281447845
# True Positve Rate: 97.5080756806645%
# No match found for mouse 'CC061-542'
# Skipping division
# Found 'CC061-543' and its infection value is '11500'
# Minimum Score:  213.67137747142118
# After Training Min:  5248
# After Infection Min:  11823
# First anomaly found after training: 928 minutes with score 213.24464973074137
# First anomaly found after infection: 323 minutes with score 198.6669074812878
# True Positve Rate: 86.99570815450643%
# Found 'CC061-544' and its infection value is '11500'
# Minimum Score:  225.5969400841295
# After Training Min:  6493
# After Infection Min:  11519
# First anomaly found after training: 2173 minutes with score 221.0037307051111
# First anomaly found after infection: 19 minutes with score 219.12692260695692
# True Positve Rate: 96.11913357400722%
# Found 'CC001-290' and its infection value is '14300'
# Minimum Score:  250.68339944883337
# After Training Min:  5283
# After Infection Min:  14321
# First anomaly found after training: 963 minutes with score 240.85837163920723
# First anomaly found after infection: 21 minutes with score 236.06052450257243
# True Positve Rate: 97.75051124744377%
# Found 'CC001-292' and its infection value is '14300'
# Minimum Score:  207.94313112822044
# After Training Min:  7079
# After Infection Min:  14612
# First anomaly found after training: 2759 minutes with score 207.92314753901178
# First anomaly found after infection: 312 minutes with score 200.19008035193843
# True Positve Rate: 93.28572951081743%
# Found 'CC005-409' and its infection value is '14300'
# Skipping division
# Found 'CC005-410' and its infection value is '14300'
# Minimum Score:  370.9793729113251
# After Training Min:  5359
# After Infection Min:  14412
# First anomaly found after training: 1039 minutes with score 362.3289028294569
# First anomaly found after infection: 112 minutes with score 368.5259289495837
# True Positve Rate: 79.72779369627507%
# Found 'CC005-411' and its infection value is '14300'
# Minimum Score:  288.2526263381222
# After Training Min:  5620
# After Infection Min:  14364
# First anomaly found after training: 1300 minutes with score 280.1336410248608
# First anomaly found after infection: 64 minutes with score 244.16867868795418
# True Positve Rate: 86.41025641025641%
# Found 'CC019-1445' and its infection value is '14300'
# Minimum Score:  247.48773285179666
# After Training Min:  5707
# After Infection Min:  14344
# First anomaly found after training: 1387 minutes with score 68.07485930233446
# First anomaly found after infection: 44 minutes with score 242.73813345471774
# True Positve Rate: 92.23864836325237%
# Found 'CC019-1451' and its infection value is '14300'
# Minimum Score:  218.39261339860093
# After Training Min:  7483
# After Infection Min:  14344
# First anomaly found after training: 3163 minutes with score 207.66526776693212
# First anomaly found after infection: 44 minutes with score 184.0398354011794
# True Positve Rate: 93.55716878402905%
# Found 'CC019-1452' and its infection value is '14300'
# Minimum Score:  236.71424847536133
# After Training Min:  5689
# After Infection Min:  14346
# First anomaly found after training: 1369 minutes with score 99.11882077113052
# First anomaly found after infection: 46 minutes with score 199.00641288471718
# True Positve Rate: 26.82926829268293%
# Found 'CC023-567' and its infection value is '14300'
# Minimum Score:  283.34220777347565
# After Training Min:  5685
# After Infection Min:  14364
# First anomaly found after training: 1365 minutes with score 270.7978490823088
# First anomaly found after infection: 64 minutes with score 199.8174422134922
# True Positve Rate: 50.427350427350426%
# Found 'CC023-568' and its infection value is '14300'
# Minimum Score:  274.25670142410047
# After Training Min:  5684
# After Infection Min:  14365
# First anomaly found after training: 1364 minutes with score 135.51917012217416
# First anomaly found after infection: 65 minutes with score 256.4223313021012
# True Positve Rate: 54.740834386852086%
# Found 'CC023-569' and its infection value is '14300'
# Minimum Score:  325.8895317891571
# After Training Min:  5683
# After Infection Min:  14368
# First anomaly found after training: 1363 minutes with score 144.0617531293414
# First anomaly found after infection: 68 minutes with score 254.91851502129845
# True Positve Rate: 22.380952380952383%
# Found 'CC023-571' and its infection value is '14300'
# Minimum Score:  172.8143837805148
# After Training Min:  15528
# After Infection Min:  15528
# First anomaly found after training: 11208 minutes with score 170.52545252216441
# First anomaly found after infection: 1228 minutes with score 170.52545252216441
# True Positve Rate: 100.0%
# Found 'CC023-572' and its infection value is '14300'
# Minimum Score:  314.69904392419977
# After Training Min:  5701
# After Infection Min:  15855
# First anomaly found after training: 1381 minutes with score 288.28323965288126
# First anomaly found after infection: 1555 minutes with score 310.58284287894304
# True Positve Rate: 82.89156626506025%
# Found 'CC023-577' and its infection value is '14300'
# Minimum Score:  197.9040991030907
# After Training Min:  14382
# After Infection Min:  14382
# First anomaly found after training: 10062 minutes with score 192.51418017412834
# First anomaly found after infection: 82 minutes with score 192.51418017412834
# True Positve Rate: 59.166666666666664%
# No match found for mouse 'CC023-578'
# Minimum Score:  279.2326570583488
# After Training Min:  5703
# After Infection Min:  16831
# First anomaly found after training: 1383 minutes with score 113.19739544391803
# First anomaly found after infection: 2531 minutes with score 276.31351086092684
# True Positve Rate: 99.70873786407766%
# No match found for mouse 'B6-102'
# Minimum Score:  336.2039993508715
# After Training Min:  6425
# After Infection Min:  20574
# First anomaly found after training: 2105 minutes with score 273.14666284240263
# First anomaly found after infection: 6274 minutes with score 330.08977940726624
# True Positve Rate: 67.39864864864865%
# No match found for mouse 'CC003-184'
# Minimum Score:  191.75334005566435
# After Training Min:  5676
# After Infection Min:  14300
# First anomaly found after training: 1356 minutes with score 189.5347949187552
# First anomaly found after infection: 0 minutes with score 0.0
# True Positve Rate: 71.13547144655952%
# Found 'CC003-187' and its infection value is '10250'
# Minimum Score:  180.5017605128329
# After Training Min:  10264
# After Infection Min:  10264
# First anomaly found after training: 5944 minutes with score 176.06464887067972
# First anomaly found after infection: 14 minutes with score 176.06464887067972
# True Positve Rate: 32.35294117647059%
# Found 'CC003-190' and its infection value is '10250'
# Minimum Score:  259.5958794337632
# After Training Min:  5075
# After Infection Min:  10265
# First anomaly found after training: 755 minutes with score 258.01315884510444
# First anomaly found after infection: 15 minutes with score 222.06984455013605
# True Positve Rate: 73.28990228013029%
# Found 'CC012-1348' and its infection value is '10250'
# Minimum Score:  307.58919343028316
# After Training Min:  5329
# After Infection Min:  10276
# First anomaly found after training: 1009 minutes with score 298.5871160848183
# First anomaly found after infection: 26 minutes with score 299.87394784742656
# True Positve Rate: 95.68014705882352%
# Found 'CC012-1349' and its infection value is '10250'
# Minimum Score:  255.64579195855492
# After Training Min:  7707
# After Infection Min:  10279
# First anomaly found after training: 3387 minutes with score 255.3371644014585
# First anomaly found after infection: 29 minutes with score 238.04007917770764
# True Positve Rate: 91.19718309859155%
# Found 'CC012-1350' and its infection value is '10250'
# Minimum Score:  283.6210363901712
# After Training Min:  5424
# After Infection Min:  10279
# First anomaly found after training: 1104 minutes with score 282.26569639854057
# First anomaly found after infection: 29 minutes with score 249.26106712250476
# True Positve Rate: 69.70185334407736%
# Found 'CC012-1354' and its infection value is '10250'
# Minimum Score:  175.26511809702947
# After Training Min:  6897
# After Infection Min:  10280
# First anomaly found after training: 2577 minutes with score 172.42072220085788
# First anomaly found after infection: 30 minutes with score 159.5894095189193
# True Positve Rate: 43.76731301939058%
# Found 'CC012-1357' and its infection value is '10250'
# Minimum Score:  206.70722276783295
# After Training Min:  5389
# After Infection Min:  10250
# First anomaly found after training: 1069 minutes with score 206.45156451899453
# First anomaly found after infection: 0 minutes with score 104.17020768563856
# True Positve Rate: 12.244897959183673%
# Found 'CC012-1359' and its infection value is '10250'
# Minimum Score:  219.3294134486435
# After Training Min:  5486
# After Infection Min:  12852
# First anomaly found after training: 1166 minutes with score 214.8162593659914
# First anomaly found after infection: 2602 minutes with score 217.87014896319081
# True Positve Rate: 71.03064066852369%
# Found 'CC025-620' and its infection value is '10250'
# Minimum Score:  304.0499681068896
# After Training Min:  5600
# After Infection Min:  13883
# First anomaly found after training: 1280 minutes with score 304.04947067251356
# First anomaly found after infection: 3633 minutes with score 293.903121854565
# True Positve Rate: 95.23809523809523%
# Found 'CC037-488' and its infection value is '10250'
# Minimum Score:  354.6648289702027
# After Training Min:  5510
# After Infection Min:  11137
# First anomaly found after training: 1190 minutes with score 354.0904205893995
# First anomaly found after infection: 887 minutes with score 352.76745357498777
# True Positve Rate: 98.6286189222884%
# Found 'CC037-489' and its infection value is '10250'
# Minimum Score:  282.87118421468955
# After Training Min:  8593
# After Infection Min:  10700
# First anomaly found after training: 4273 minutes with score 119.72777657073902
# First anomaly found after infection: 450 minutes with score 261.01630726265563
# True Positve Rate: 95.83333333333334%
# Found 'CC037-490' and its infection value is '10250'
# Minimum Score:  248.73536855609848
# After Training Min:  5272
# After Infection Min:  11312
# First anomaly found after training: 952 minutes with score 243.10271193542098
# First anomaly found after infection: 1062 minutes with score 229.1628553993766
# True Positve Rate: 95.70999570999571%
# Found 'CC037-491' and its infection value is '10250'
# Minimum Score:  299.5679224646577
# After Training Min:  5175
# After Infection Min:  10672
# First anomaly found after training: 855 minutes with score 298.40201874201847
# First anomaly found after infection: 422 minutes with score 293.3736942650066
# True Positve Rate: 85.45237146273415%
# Found 'CC037-492' and its infection value is '10250'
# Minimum Score:  231.6455902761349
# After Training Min:  7724
# After Infection Min:  10252
# First anomaly found after training: 3404 minutes with score 224.67717789360202
# First anomaly found after infection: 2 minutes with score 226.83874414101044
# True Positve Rate: 99.03644742354419%
# Found 'CC037-493' and its infection value is '10250'
# Minimum Score:  291.4918880926367
# After Training Min:  5336
# After Infection Min:  10318
# First anomaly found after training: 1016 minutes with score 289.08990946494083
# First anomaly found after infection: 68 minutes with score 275.50581098825666
# True Positve Rate: 98.47045564321365%
# No match found for mouse 'C57Bl6-104'
# Minimum Score:  258.26331182775
# After Training Min:  5481
# After Infection Min:  11205
# First anomaly found after training: 1161 minutes with score 248.17487966405557
# First anomaly found after infection: 955 minutes with score 251.54711012752836
# True Positve Rate: 99.04556650246306%
# Found 'C57Bl6-105' and its infection value is '10000'
# Minimum Score:  218.65120288311937
# After Training Min:  11456
# After Infection Min:  11456
# First anomaly found after training: 7136 minutes with score 217.97268099687653
# First anomaly found after infection: 1456 minutes with score 217.97268099687653
# True Positve Rate: 100.0%
# Found 'C57Bl6-106' and its infection value is '10000'
# Minimum Score:  307.0090510107615
# After Training Min:  5553
# After Infection Min:  11600
# First anomaly found after training: 1233 minutes with score 300.9282394370759
# First anomaly found after infection: 1600 minutes with score 301.4318863699559
# True Positve Rate: 91.01796407185628%
# Found 'CC019-1513' and its infection value is '10000'
# Minimum Score:  213.76793638280793
# After Training Min:  5397
# After Infection Min:  10043
# First anomaly found after training: 1077 minutes with score 170.79676270060338
# First anomaly found after infection: 43 minutes with score 196.80871787812396
# True Positve Rate: 44.35146443514644%
# Found 'CC019-1514' and its infection value is '10000'
# Minimum Score:  272.5865240632977
# After Training Min:  6037
# After Infection Min:  11455
# First anomaly found after training: 1717 minutes with score 258.45462232489405
# First anomaly found after infection: 1455 minutes with score 263.71916170085706
# True Positve Rate: 84.82220294882914%
# Found 'CC024-363' and its infection value is '10000'
# Minimum Score:  287.60451535795664
# After Training Min:  5156
# After Infection Min:  10054
# First anomaly found after training: 836 minutes with score 284.4306309360288
# First anomaly found after infection: 54 minutes with score 259.7503031981292
# True Positve Rate: 98.4688995215311%
# Found 'CC024-364' and its infection value is '10000'
# Minimum Score:  387.14817333443597
# After Training Min:  5994
# After Infection Min:  10058
# First anomaly found after training: 1674 minutes with score 383.76997164934374
# First anomaly found after infection: 58 minutes with score 345.44450981955856
# True Positve Rate: 14.847161572052403%
# Found 'CC024-365' and its infection value is '10000'
# Minimum Score:  255.90600592776946
# After Training Min:  10072
# After Infection Min:  10072
# First anomaly found after training: 5752 minutes with score 224.7518262030623
# First anomaly found after infection: 72 minutes with score 224.7518262030623
# True Positve Rate: 41.17647058823529%
# Found 'CC025-603' and its infection value is '10000'
# Minimum Score:  244.25222156064027
# After Training Min:  8059
# After Infection Min:  12790
# First anomaly found after training: 3739 minutes with score 241.45620520134474
# First anomaly found after infection: 2790 minutes with score 242.79645356628635
# True Positve Rate: 50.943396226415096%
# Found 'CC027-392' and its infection value is '10000'
# Minimum Score:  247.7515181480296
# After Training Min:  5990
# After Infection Min:  10134
# First anomaly found after training: 1670 minutes with score 236.28424045682414
# First anomaly found after infection: 134 minutes with score 246.35083265124848
# True Positve Rate: 98.95531983285117%
# Found 'CC027-393' and its infection value is '10000'
# Minimum Score:  248.8681512967733
# After Training Min:  5688
# After Infection Min:  11357
# First anomaly found after training: 1368 minutes with score 239.8035017784798
# First anomaly found after infection: 1357 minutes with score 226.4436164261224
# True Positve Rate: 99.55685618729096%
# Found 'CC042-330' and its infection value is '10000'
# Minimum Score:  297.94845836240853
# After Training Min:  7152
# After Infection Min:  10164
# First anomaly found after training: 2832 minutes with score 58.0374295961829
# First anomaly found after infection: 164 minutes with score 290.51699818683255
# True Positve Rate: 93.67541766109785%
# Found 'CC042-331' and its infection value is '10000'
# Minimum Score:  202.72191759825478
# After Training Min:  7151
# After Infection Min:  10102
# First anomaly found after training: 2831 minutes with score 178.24963050438942
# First anomaly found after infection: 102 minutes with score 202.68606470069358
# True Positve Rate: 79.4486215538847%
# Found 'CC042-332' and its infection value is '10000'
# Minimum Score:  214.3951826309363
# After Training Min:  7161
# After Infection Min:  10000
# First anomaly found after training: 2841 minutes with score 60.06995013496754
# First anomaly found after infection: 0 minutes with score 183.45884528301588
# True Positve Rate: 76.3874873864783%
# Found 'CC006-510' and its infection value is '10500'
# Minimum Score:  86.47497518509152
# After Training Min:  6900
# After Infection Min:  16942
# First anomaly found after training: 2580 minutes with score 78.56599238558533
# First anomaly found after infection: 6442 minutes with score 78.16068963799671
# True Positve Rate: 70.0%
# Found 'CC017-426' and its infection value is '10500'
# Skipping division
# Found 'CC036-290' and its infection value is '10500'
# Minimum Score:  277.7549845405517
# After Training Min:  11405
# After Infection Min:  11405
# First anomaly found after training: 7085 minutes with score 267.5363491454601
# First anomaly found after infection: 905 minutes with score 267.5363491454601
# True Positve Rate: 100.0%
# Found 'CC043-607' and its infection value is '10500'
# Minimum Score:  201.36621655360017
# After Training Min:  5717
# After Infection Min:  10811
# First anomaly found after training: 1397 minutes with score 197.76320773995747
# First anomaly found after infection: 311 minutes with score 190.5320818014029
# True Positve Rate: 0.0%
# Found 'CC058-317' and its infection value is '10500'
# Minimum Score:  279.0625418755843
# After Training Min:  5980
# After Infection Min:  12808
# First anomaly found after training: 1660 minutes with score 278.54329228872274
# First anomaly found after infection: 2308 minutes with score 278.67355924784005
# True Positve Rate: 97.42268041237114%
# Found 'CC058-318' and its infection value is '10500'
# Minimum Score:  247.94933030675972
# After Training Min:  9466
# After Infection Min:  11362
# First anomaly found after training: 5146 minutes with score 241.14135815198307
# First anomaly found after infection: 862 minutes with score 238.75890984173157
# True Positve Rate: 99.86807387862797%
# Found 'CC058-319' and its infection value is '10500'
# Minimum Score:  201.8908846467724
# After Training Min:  7169
# After Infection Min:  11443
# First anomaly found after training: 2849 minutes with score 200.6196615621127
# First anomaly found after infection: 943 minutes with score 198.35733463073797
# True Positve Rate: 99.24960505529225%
# Found 'CC061-565' and its infection value is '10500'
# Minimum Score:  226.52964992160938
# After Training Min:  8882
# After Infection Min:  10828
# First anomaly found after training: 4562 minutes with score 214.62500807648735
# First anomaly found after infection: 328 minutes with score 225.08961150725193
# True Positve Rate: 52.0%
# Found 'CC001-325' and its infection value is '10100'
# Minimum Score:  209.61900986923695
# After Training Min:  6910
# After Infection Min:  10377
# First anomaly found after training: 2590 minutes with score 167.59816367499866
# First anomaly found after infection: 277 minutes with score 200.11370458839747
# True Positve Rate: 99.12371134020619%
# Found 'CC025-645' and its infection value is '10100'
# Minimum Score:  246.40440991049502
# After Training Min:  6913
# After Infection Min:  10121
# First anomaly found after training: 2593 minutes with score 243.57154466484633
# First anomaly found after infection: 21 minutes with score 164.8590554326439
# True Positve Rate: 96.3076923076923%
# Found 'CC027-426' and its infection value is '10100'
# Minimum Score:  318.4646177692241
# After Training Min:  5048
# After Infection Min:  10124
# First anomaly found after training: 728 minutes with score 317.4946698336717
# First anomaly found after infection: 24 minutes with score 139.68194873299632
# True Positve Rate: 98.85057471264368%
# Found 'CC038-669' and its infection value is '10100'
# Minimum Score:  225.32323154029672
# After Training Min:  7640
# After Infection Min:  10130
# First anomaly found after training: 3320 minutes with score 216.05154325688562
# First anomaly found after infection: 30 minutes with score 198.89223630487908
# True Positve Rate: 52.083333333333336%
# Found 'CC042-347' and its infection value is '10100'
# Minimum Score:  14.45462007864279
# After Training Min:  13013
# After Infection Min:  13013
# First anomaly found after training: 8693 minutes with score 13.31036984221737
# First anomaly found after infection: 2913 minutes with score 13.31036984221737
# True Positve Rate: 100.0%
# Found 'CC042-348' and its infection value is '10100'
# Minimum Score:  161.57902882648727
# After Training Min:  6927
# After Infection Min:  10648
# First anomaly found after training: 2607 minutes with score 134.21918535871794
# First anomaly found after infection: 548 minutes with score 154.5544600507053
# True Positve Rate: 99.851805631386%
# Found 'CC042-349' and its infection value is '10100'
# Minimum Score:  281.60715248420496
# After Training Min:  6938
# After Infection Min:  10854
# First anomaly found after training: 2618 minutes with score 237.29138226196812
# First anomaly found after infection: 754 minutes with score 279.467596729564
# True Positve Rate: 88.4393063583815%
# Found 'CC043-562' and its infection value is '10100'
# Minimum Score:  188.445114186539
# After Training Min:  9751
# After Infection Min:  10109
# First anomaly found after training: 5431 minutes with score 180.5822735932553
# First anomaly found after infection: 9 minutes with score 187.807471058322
# True Positve Rate: 0.0%
# No match found for mouse 'CC043-563'
# Minimum Score:  213.56964530789242
# After Training Min:  6747
# After Infection Min:  12603
# First anomaly found after training: 2427 minutes with score 190.0759560734358
# First anomaly found after infection: 2503 minutes with score 206.37989747835798
# True Positve Rate: 99.863737012434%
# Found 'CC043-564' and its infection value is '10100'
# Minimum Score:  179.65561538893968
# After Training Min:  8265
# After Infection Min:  10100
# First anomaly found after training: 3945 minutes with score 170.94126138364987
# First anomaly found after infection: 0 minutes with score 427.66323645190437
# True Positve Rate: 0.0%
# Found 'CC051-615' and its infection value is '10100'
# Minimum Score:  173.73464512240525
# After Training Min:  7232
# After Infection Min:  10242
# First anomaly found after training: 2912 minutes with score 172.63662989337405
# First anomaly found after infection: 142 minutes with score 169.25409725540175
# True Positve Rate: 97.15082068751936%
# Found 'CC053-366' and its infection value is '10100'
# Minimum Score:  136.75609042381097
# After Training Min:  6504
# After Infection Min:  10746
# First anomaly found after training: 2184 minutes with score 109.81408600270026
# First anomaly found after infection: 646 minutes with score 129.86062574626635
# True Positve Rate: 74.33155080213903%
# Found 'CC053-370' and its infection value is '10100'
# Minimum Score:  113.98577998235459
# After Training Min:  6955
# After Infection Min:  11983
# First anomaly found after training: 2635 minutes with score 104.45908784184081
# First anomaly found after infection: 1883 minutes with score 111.8450665445531
# True Positve Rate: 61.29032258064516%
# Found 'CC053-371' and its infection value is '10100'
# Minimum Score:  42.98244832383455
# After Training Min:  10897
# After Infection Min:  10897
# First anomaly found after training: 6577 minutes with score 41.19658032572352
# First anomaly found after infection: 797 minutes with score 41.19658032572352
# True Positve Rate: 100.0%
# Found 'CC057-704' and its infection value is '10100'
# Skipping division
# Found 'CC057-705' and its infection value is '10100'
# Minimum Score:  198.22003088656584
# After Training Min:  5904
# After Infection Min:  14116
# First anomaly found after training: 1584 minutes with score 190.20591668942234
# First anomaly found after infection: 4016 minutes with score 196.01653824260427
# True Positve Rate: 77.59562841530054%
# Found 'C57Bl6-108' and its infection value is '10200'
# Minimum Score:  372.0099282449168
# After Training Min:  6399
# After Infection Min:  10214
# First anomaly found after training: 2079 minutes with score 367.2541051889011
# First anomaly found after infection: 14 minutes with score 358.8230384933783
# True Positve Rate: 91.91666666666667%
# Found 'CC017-394' and its infection value is '10200'
# Minimum Score:  259.49653582071267
# After Training Min:  7064
# After Infection Min:  14233
# First anomaly found after training: 2744 minutes with score 256.8986427646997
# First anomaly found after infection: 4033 minutes with score 247.34285021604023
# True Positve Rate: 83.01886792452831%
# Found 'CC017-395' and its infection value is '10200'
# Minimum Score:  277.38000969131576
# After Training Min:  5997
# After Infection Min:  13829
# First anomaly found after training: 1677 minutes with score 273.23550105984924
# First anomaly found after infection: 3629 minutes with score 256.8573823744401
# True Positve Rate: 52.38095238095239%
# Found 'CC024-371' and its infection value is '10200'
# Minimum Score:  201.15510071569997
# After Training Min:  10081
# After Infection Min:  10218
# First anomaly found after training: 5761 minutes with score 171.72328025045272
# First anomaly found after infection: 18 minutes with score 120.30985530732988
# True Positve Rate: 54.6875%
# Found 'CC027-400' and its infection value is '10200'
# Minimum Score:  276.88070824156915
# After Training Min:  5994
# After Infection Min:  10221
# First anomaly found after training: 1674 minutes with score 269.37089790469895
# First anomaly found after infection: 21 minutes with score 263.5984340098826
# True Positve Rate: 99.72617743702081%
# Found 'CC027-401' and its infection value is '10200'
# Minimum Score:  310.3379671316697
# After Training Min:  6720
# After Infection Min:  11029
# First anomaly found after training: 2400 minutes with score 306.7947715330092
# First anomaly found after infection: 829 minutes with score 309.6729644671299
# True Positve Rate: 99.37686939182453%
# Found 'CC027-403' and its infection value is '10200'
# Minimum Score:  325.1936970495813
# After Training Min:  5557
# After Infection Min:  11395
# First anomaly found after training: 1237 minutes with score 318.6438716123825
# First anomaly found after infection: 1195 minutes with score 322.015864456612
# True Positve Rate: 94.6402421165674%
# Found 'CC041-1752' and its infection value is '10200'
# Minimum Score:  292.95573997862124
# After Training Min:  6951
# After Infection Min:  10456
# First anomaly found after training: 2631 minutes with score 289.09021050560017
# First anomaly found after infection: 256 minutes with score 289.9490090994528
# True Positve Rate: 75.47169811320755%
# Found 'CC041-1753' and its infection value is '10200'
# Minimum Score:  279.13527653943436
# After Training Min:  6189
# After Infection Min:  10970
# First anomaly found after training: 1869 minutes with score 265.28541734435083
# First anomaly found after infection: 770 minutes with score 263.84050253872897
# True Positve Rate: 88.74458874458875%
# Found 'CC041-1754' and its infection value is '10200'
# Minimum Score:  302.67914522145145
# After Training Min:  5671
# After Infection Min:  10477
# First anomaly found after training: 1351 minutes with score 297.20959041841814
# First anomaly found after infection: 277 minutes with score 291.4001241432777
# True Positve Rate: 81.45454545454545%
# Found 'CC041-1758' and its infection value is '10200'
# Minimum Score:  298.9860420883054
# After Training Min:  5512
# After Infection Min:  10201
# First anomaly found after training: 1192 minutes with score 294.24541309892317
# First anomaly found after infection: 1 minutes with score 296.802123382467
# True Positve Rate: 77.21518987341773%
# Found 'CC041-1759' and its infection value is '10200'
# Minimum Score:  270.92274931284965
# After Training Min:  5818
# After Infection Min:  10200
# First anomaly found after training: 1498 minutes with score 268.24201969786014
# First anomaly found after infection: 0 minutes with score 227.25605163377156
# True Positve Rate: 46.48829431438127%
# Found 'CC041-1760' and its infection value is '10200'
# Minimum Score:  157.30237871166264
# After Training Min:  9501
# After Infection Min:  11162
# First anomaly found after training: 5181 minutes with score 156.47545504162144
# First anomaly found after infection: 962 minutes with score 152.58598268049604
# True Positve Rate: 96.75324675324676%

# %%
# Make all lists into arrays
ms = np.array(min_scores)
fat = np.array(first_anom_train)
fai = np.array(first_anom_inf)
st = np.array(score_train)
si = np.array(score_infec)
tprs = np.array(tpr)

# %%
# Create the data for the table (calculates statistics)
data = {
    'column_1': [round(np.mean(ms),2), round(np.mean(fat),2), round(np.mean(fai),2), round(np.mean(st),2), round(np.mean(si),2), round(np.mean(tprs)*100,2)],
    'column_2': [round(np.std(ms),2), round(np.std(fat),2), round(np.std(fai),2), round(np.std(st),2), round(np.std(si),2), round(np.std(tprs)*100,2)],
    'column_3': [round(np.percentile(ms, 25),2), round(np.percentile(fat, 25),2), round(np.percentile(fai, 25),2), round(np.percentile(st, 25),2), round(np.percentile(si, 25),2), round(np.percentile(tprs, 25)*100,2)],
    'column_4': [round(np.percentile(ms, 50),2), round(np.percentile(fat, 50),2), round(np.percentile(fai, 50),2), round(np.percentile(st, 50),2), round(np.percentile(si, 50),2), round(np.percentile(tprs, 50)*100,2)],
    'column_5': [round(np.percentile(ms, 75),2), round(np.percentile(fat, 75),2), round(np.percentile(fai, 75),2), round(np.percentile(st, 75),2), round(np.percentile(si, 75),2), round(np.percentile(tprs, 75)*100,2)]
}

# %%
# Create a DataFrame
df = pd.DataFrame(data)

# Set row names (index)
row_names = ['Minimum Score', 'First Anomaly Time After Training', 'First Anomaly Time After Infection', 'First Anomaly Score After Training', 'First Anomaly Score After Infection  ', 'True Positive Rate']
df.index = row_names

# Set column names
column_names = ['Mean', 'Standard Deviation', 'Quartile 1 (25%)', 'Quartile 2 (Med)', 'Quartile 3 (75%)']
df.columns = column_names

# %%
# Saving the Table
# Create a table visualization using matplotlib
fig, ax = plt.subplots(figsize=(6, 4))
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, rowLabels=df.index, loc='center')
table.auto_set_font_size(False)
table.set_fontsize(14)
table.scale(2.5, 2)  # Adjust the scaling factor as per your requirements

# Modify the column names as dark color boxes
for i, col_name in enumerate(df.columns):
    cell = table[0, i]
    cell.set_text_props(weight='bold', color='white')
    cell.set_facecolor('darkgray')
    
# Save the table as an image file
plt.savefig('table_statistics_3days.png', bbox_inches='tight', facecolor='white')
