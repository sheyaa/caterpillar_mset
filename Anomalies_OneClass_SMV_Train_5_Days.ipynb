# %% [markdown]
# # One Class Support Vector Machines

# %% [markdown]
# ## Importing Libraries

# %%
# Data Processing
import numpy as np
import pandas as pd
from collections import Counter

# Importing tde
import tde

import matplotlib.pyplot as plt

# Model and Performance
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.svm import OneClassSVM
from sklearn.metrics import classification_report #for model performance evaluation

# To generate the for loops
import glob
import os
from matplotlib import ticker

# %% [markdown]
# ## Data Management

# %%
# READ INFECTION TIME DATA
infection_data = pd.read_excel('/Users/yoddmena/Downloads/Research/Telemetry_edited/MRSA - Master sheet.xlsx', index_col=0)

# READ AND EXTRACT DATA FROM FOLDER CONTAINING EXCEL SHEETS
folder = "/Users/yoddmena/Downloads/Research/Telemetry_edited/"
files = glob.glob( folder + "Ex *.xlsx" )

# %%
# CREATE A LIST OF TEMPERATURES
temp = []

for file in files:
    df = pd.read_excel(file)
    file_temp = df.iloc[:, 3::2]  # slicing the data for only temperature
    
    # Ensure that the number of minutes matches the number of temperature columns
    num_temp_columns = file_temp.shape[1]
    
    # Iterate over every other column in file_temp
    for j in range(0, num_temp_columns):
        # Extract the specific temperature column and its corresponding minutes
        column_name = file_temp.columns[j]
        temperature = file_temp[column_name]
        
        # Append the temperature and minutes to each lists
        temp.append(temperature)

# %% [markdown]
# ## Creating Data Frames

# %%
##### INFECTION DATA
infection_data = infection_data.iloc[:,[1,9]]
infection_data = infection_data.T # transpose the data

infection_data.columns = infection_data.iloc[0] # Assign the values of the first row as the new column names

infection_data = infection_data[1:] # Remove the first row (previous column names)


##### TEMPERATURE DATA
df_temp = pd.DataFrame(temp)
df_temp = df_temp.T # transpose the data

df_temp.columns = df_temp.columns.astype(str).str.split(' ').str[0] # Rename columns keeping only the first word

# %% [markdown]
# ## Scores

# %%
# IMPORTING THE SVM MODEL
# this model is from SckiKit Learn
model = svm.OneClassSVM()

# SIGMOID DEFINITION
# we will use the sigmoid function to make our scores be a numerical value that lies between 0 and 1

beta = (2/700) # 700 is the largest value
def sigmoid(scores, beta):
    return 1 / (1 + np.exp(-beta * scores))

# %%
#fig,ax = plt.subplots(2,1,figsize=(15,10), sharex = False)
#fig.set_facecolor("white")

train_end = 7200 #(5 days)
shift = 2*360 # since the period is 6 hours (360) and we do this twice

# LISTS
# First anomalies after infection
min_scores = []
first_anom_train = []
first_anom_inf = []
score_train = []
score_infec = []
tpr = []

for i in range(0, df_temp.shape[1]): #df_temp.shape[1]
    #ax[0].cla()  # clear axis 0-1
    #ax[1].cla()
    
    #mice_min = range(0, df_temp.shape[0]) # Get the specific minutes for the current temperature time series
    
    temp_value = df_temp.iloc[:, i] # extract the temperature values for the current column
    mice_temp = df_temp.iloc[:, i].to_frame() # converting temp list to data frame
    
    names = mice_temp.columns[0] # get the column name for the current file
    
    # Filing in missing data
    temp_value_fw = temp_value.fillna(method='ffill') # foward fill
    temp_value_bw = temp_value_fw.fillna(method='bfill') # backward fill after forward fill
    
    # Time Delay Embedding
    temp_tde = tde.tde(temp_value_bw) # using the tde file
    temp_tde = temp_tde.T # transporting the data
    
    ##################################################################
    # Fit the Data on the first 5 days (5*24*60) 
    model.fit(temp_tde[:train_end+1,:])
    
    # Predict the Data
    predict_train_data = model.predict(temp_tde[:train_end+1,:]) # predict on training data
    predict_test_data = model.predict(temp_tde[train_end+1:,:]) # predicting on test data
    
    # Scores
    scores_train_data = model.score_samples(temp_tde[:train_end+1,:]) # scores on training data 
    scores_test_data = model.score_samples(temp_tde[train_end+1:,:]) # scores on test data
    
    threshold = model.offset_
    
    ##################################################################
    # Combine training and testing scores and predictions
    combined_scores= np.concatenate((scores_train_data, scores_test_data), axis=0)
    combined_predictions = np.concatenate((predict_train_data, predict_test_data), axis=0)
    
    time = np.arange(temp_tde.shape[0])+(shift) # 2 times the time delay shift
    
    # Minimum score
    min_score = scores_train_data.min()
    
    # Find the indices of the anomalies
    anomaly_indices = np.where(combined_scores <= min_score)[0] #finding the values where its -1 (anomaly)
    time_2 = anomaly_indices + (shift) # shifting the time for plotting
    '''
    ##################################################################
    # Plotting 1st Graph
    ax[0].plot(time, combined_scores, '-', color='#6693F5', alpha=0.75)  # Plot the scores with blue color #[:100]
    ax[0].grid()
    ax[0].set_ylabel("Score", fontsize=14)
    ax[0].set_title(f"Anomalies found using SckiKit Learn's threshold for '{names}'", fontsize=14)
    ax[0].set_xlim(-10,26000)
    ax[0].set_ylim(0,700)
    ax[0].axhline(y = threshold, color='red', linestyle='-', label='threshold')
    # Plot the anomalies with red color
    #ax[0].plot(time_2, combined_scores[anomaly_indices], '', color='purple') #[:100]
    #ax[0].axhline(y=min_score, color='red', linestyle='-')
    '''
    ##################################################################
    # Plotting infection time
    matching_columns = set(mice_temp.columns).intersection(infection_data.columns)
    
    if matching_columns:
        column_name = matching_columns.pop()
        infection_time = infection_data.loc['Aprprox Infection Minute', column_name]
        # Add a vertical line at the infection time
        #ax[1].axvline(x = infection_time, color='purple', linestyle='-', label='Infection time')
        print(f"Found '{column_name}' and its infection value is '{infection_time}'")
    else:
        print(f"No match found for mouse '{names}'")
    
    ##################################################################
    # Find the index at which the first score is less than min_score
    boolean = combined_scores < min_score
    anom_train = np.argmax(boolean) #+shift
    anom_infec = np.argmax(boolean[infection_time-shift:]) + infection_time 
    
    # Get the corresponding value
    value = combined_scores[anom_train]
    value_1 = combined_scores[anom_infec-shift]
    
    # Calculating the time first anomaly was found after training and infection
    time_aft_train = (anom_train + shift) - train_end
    time_aft_infection = anom_infec - infection_time
    
    # Calculating the amount of false negatives (between end of train and infection time)
    count_false_neg = np.count_nonzero(boolean[train_end:infection_time])
    
    # Calculating the amount of true positives (infection time)
    count_true_pos = np.count_nonzero(boolean[infection_time:]) 
    
    # Calculating true positive rate
    # Check if the denominator is zero
    if (count_true_pos + count_false_neg) == 0:
        print("Skipping division ")
        continue  # Skip this iteration and move to the next number
        
    TPR = count_true_pos / (count_true_pos + count_false_neg)
    '''
    ##################################################################
    # Plotting 2nd Graph
    ax[1].plot(time, combined_scores, '-', color='#6693F5', alpha=0.75)  # Plot the scores with blue color #[:100]
    ax[1].plot(time_2, combined_scores[anomaly_indices], '', color='purple') #coloring anomalies
    ax[1].grid()
    ax[1].set_ylabel("Score", fontsize=14)
    ax[1].set_xlabel("Minutes", fontsize=14)
    ax[1].set_title(f"Anomalies found using our threshold for '{names}'", fontsize=14)
    #ax[1].set_xlim(infection_time-5,infection_time+30)
    ax[1].set_xlim(-10,26000)
    ax[1].set_ylim(0,700)
    
    ##################################################################
    # Plotting Horizontal and Vertical Lines
    ax[1].axvline(x = anom_train+shift, color='blue', linestyle='--', label='First anomaly after training') # when the first value is less the minimum value
    ax[1].axvline(x = train_end, color='green', linestyle='-', label='End of training data')
    ax[1].axhline(y=min_score, color='red', linestyle='-', label='Threshold')
    ax[1].axvline(x = anom_infec, color='orange', linestyle ='-', label='First anomaly after infection')
    #ax[1].axhline(y=value, color='blue', linestyle='--', label='value')
    #ax[1].axhline(y=value_1, color='orange', linestyle='-', label='value_1')
    ax[1].legend()
    '''
    ##################################################################
    # Print Values
    print("Minimum Score: ", min_score)
    print("After Training Min: ", anom_train+shift)
    print("After Infection Min: ", anom_infec)
    print(f"First anomaly found after training: {time_aft_train} minutes with score {value}")
    print(f"First anomaly found after infection: {time_aft_infection} minutes with score {value_1}")
    print(f"True Positve Rate: {TPR*100}%")
    
    ##################################################################
    # Appending to Lists
    min_scores.append(min_score)
    first_anom_train.append(time_aft_train)
    first_anom_inf.append(time_aft_infection)
    score_train.append(value)
    score_infec.append(value_1)
    tpr.append(TPR)
# Out:
# Found 'CC006-315' and its infection value is '10300'
# Minimum Score:  421.2324136337255
# After Training Min:  11049
# After Infection Min:  11049
# First anomaly found after training: 3849 minutes with score 389.21973137373834
# First anomaly found after infection: 749 minutes with score 389.21973137373834
# True Positve Rate: 100.0%
# Found 'CC006-316' and its infection value is '10300'
# Minimum Score:  435.68503381684445
# After Training Min:  10464
# After Infection Min:  10464
# First anomaly found after training: 3264 minutes with score 383.8489128994704
# First anomaly found after infection: 164 minutes with score 383.8489128994704
# True Positve Rate: 99.06222681395533%
# Found 'CC006-317' and its infection value is '10300'
# Minimum Score:  411.4133279779127
# After Training Min:  12667
# After Infection Min:  12667
# First anomaly found after training: 5467 minutes with score 380.27826118432756
# First anomaly found after infection: 2367 minutes with score 380.27826118432756
# True Positve Rate: 100.0%
# Found 'CC019-1392' and its infection value is '10300'
# Minimum Score:  281.34609476049275
# After Training Min:  8211
# After Infection Min:  10322
# First anomaly found after training: 1011 minutes with score 257.8433151119965
# First anomaly found after infection: 22 minutes with score 249.90965888073958
# True Positve Rate: 98.3957219251337%
# No match found for mouse 'CC019-1393'
# Minimum Score:  69.63695623785077
# After Training Min:  18196
# After Infection Min:  18196
# First anomaly found after training: 10996 minutes with score 67.48954915843206
# First anomaly found after infection: 7896 minutes with score 67.48954915843206
# True Positve Rate: 100.0%
# Found 'CC043-455' and its infection value is '10300'
# Skipping division
# Found 'CC043-456' and its infection value is '10300'
# Minimum Score:  342.974015019986
# After Training Min:  8483
# After Infection Min:  12115
# First anomaly found after training: 1283 minutes with score 333.1572322513105
# First anomaly found after infection: 1815 minutes with score 324.98855536982165
# True Positve Rate: 16.129032258064516%
# Found 'CC043-457' and its infection value is '10300'
# Skipping division
# Found 'CC051-489' and its infection value is '10300'
# Minimum Score:  309.07945223738676
# After Training Min:  10700
# After Infection Min:  10700
# First anomaly found after training: 3500 minutes with score 249.22047328812607
# First anomaly found after infection: 400 minutes with score 249.22047328812607
# True Positve Rate: 98.08510638297872%
# Found 'CC051-490' and its infection value is '10300'
# Minimum Score:  268.9559288285959
# After Training Min:  11064
# After Infection Min:  11064
# First anomaly found after training: 3864 minutes with score 234.25967257723573
# First anomaly found after infection: 764 minutes with score 234.25967257723573
# True Positve Rate: 100.0%
# Found 'CC057-610' and its infection value is '10300'
# Minimum Score:  262.46813758513713
# After Training Min:  12813
# After Infection Min:  12813
# First anomaly found after training: 5613 minutes with score 257.5158887168758
# First anomaly found after infection: 2513 minutes with score 257.5158887168758
# True Positve Rate: 100.0%
# Found 'CC002-607' and its infection value is '11250'
# Minimum Score:  143.20577125370835
# After Training Min:  14450
# After Infection Min:  14450
# First anomaly found after training: 7250 minutes with score 124.95759516629516
# First anomaly found after infection: 3200 minutes with score 124.95759516629516
# True Positve Rate: 100.0%
# Found 'CC002-609' and its infection value is '11250'
# Minimum Score:  269.0010992931642
# After Training Min:  10762
# After Infection Min:  11481
# First anomaly found after training: 3562 minutes with score 265.99003235294
# First anomaly found after infection: 231 minutes with score 264.2908222670406
# True Positve Rate: 98.81914232442512%
# Found 'CC002-610' and its infection value is '11250'
# Minimum Score:  319.4168097478975
# After Training Min:  10307
# After Infection Min:  11262
# First anomaly found after training: 3107 minutes with score 312.5964192067478
# First anomaly found after infection: 12 minutes with score 268.9242261047016
# True Positve Rate: 95.63679245283019%
# Found 'CC003-178' and its infection value is '11250'
# Minimum Score:  448.7573444143157
# After Training Min:  11274
# After Infection Min:  11274
# First anomaly found after training: 4074 minutes with score 389.8892006725562
# First anomaly found after infection: 24 minutes with score 389.8892006725562
# True Positve Rate: 99.87357774968395%
# Found 'CC003-179' and its infection value is '11250'
# Minimum Score:  394.10898200162626
# After Training Min:  11275
# After Infection Min:  11275
# First anomaly found after training: 4075 minutes with score 348.4360188021974
# First anomaly found after infection: 25 minutes with score 348.4360188021974
# True Positve Rate: 86.4%
# Found 'CC003-180' and its infection value is '11250'
# Minimum Score:  393.7797114805304
# After Training Min:  11283
# After Infection Min:  11283
# First anomaly found after training: 4083 minutes with score 338.25193286875714
# First anomaly found after infection: 33 minutes with score 338.25193286875714
# True Positve Rate: 52.63157894736842%
# Found 'CC005-433' and its infection value is '11250'
# Minimum Score:  545.8995497456687
# After Training Min:  8110
# After Infection Min:  11282
# First anomaly found after training: 910 minutes with score 543.6589512549856
# First anomaly found after infection: 32 minutes with score 506.711288768704
# True Positve Rate: 87.5%
# Found 'CC005-434' and its infection value is '11250'
# Minimum Score:  477.7032118541281
# After Training Min:  11285
# After Infection Min:  11285
# First anomaly found after training: 4085 minutes with score 408.23382053019327
# First anomaly found after infection: 35 minutes with score 408.23382053019327
# True Positve Rate: 99.74603174603175%
# Found 'CC005-435' and its infection value is '11250'
# Minimum Score:  448.1968005290706
# After Training Min:  11290
# After Infection Min:  11290
# First anomaly found after training: 4090 minutes with score 213.86717500186967
# First anomaly found after infection: 40 minutes with score 213.86717500186967
# True Positve Rate: 42.10526315789473%
# No match found for mouse 'CC011-564'
# Minimum Score:  377.92537789917475
# After Training Min:  8166
# After Infection Min:  11287
# First anomaly found after training: 966 minutes with score 371.1287617153118
# First anomaly found after infection: 37 minutes with score 266.70869681008355
# True Positve Rate: 97.37704918032787%
# No match found for mouse 'CC011-565'
# Minimum Score:  435.6420496710744
# After Training Min:  8097
# After Infection Min:  11307
# First anomaly found after training: 897 minutes with score 422.3496556263927
# First anomaly found after infection: 57 minutes with score 313.21565814337873
# True Positve Rate: 90.65573770491804%
# No match found for mouse 'CC011-566'
# Minimum Score:  308.2042771574363
# After Training Min:  11314
# After Infection Min:  11314
# First anomaly found after training: 4114 minutes with score 308.0620719891742
# First anomaly found after infection: 64 minutes with score 308.0620719891742
# True Positve Rate: 68.85245901639344%
# Found 'CC013-642' and its infection value is '11250'
# Minimum Score:  406.93202759480715
# After Training Min:  8291
# After Infection Min:  11429
# First anomaly found after training: 1091 minutes with score 364.16364151283386
# First anomaly found after infection: 179 minutes with score 390.74357047428725
# True Positve Rate: 97.30134932533733%
# Found 'CC013-643' and its infection value is '11250'
# Minimum Score:  418.9239435179347
# After Training Min:  9049
# After Infection Min:  11368
# First anomaly found after training: 1849 minutes with score 418.904964533445
# First anomaly found after infection: 118 minutes with score 411.56390777030293
# True Positve Rate: 78.4688995215311%
# Found 'CC013-644' and its infection value is '11250'
# Minimum Score:  353.3305600521069
# After Training Min:  8645
# After Infection Min:  11487
# First anomaly found after training: 1445 minutes with score 283.52360596805056
# First anomaly found after infection: 237 minutes with score 352.74381507087617
# True Positve Rate: 93.51145038167938%
# No match found for mouse 'B6-103'
# Minimum Score:  453.813580559944
# After Training Min:  8152
# After Infection Min:  11324
# First anomaly found after training: 952 minutes with score 431.7654008459458
# First anomaly found after infection: 74 minutes with score 364.02869679644357
# True Positve Rate: 98.40796019900498%
# Found 'CC001-364' and its infection value is '10250'
# Skipping division
# Found 'CC001-366' and its infection value is '10250'
# Skipping division
# Found 'CC003-225' and its infection value is '10250'
# Minimum Score:  354.3982964326489
# After Training Min:  18951
# After Infection Min:  18951
# First anomaly found after training: 11751 minutes with score 315.58677128996817
# First anomaly found after infection: 8701 minutes with score 315.58677128996817
# True Positve Rate: 100.0%
# Found 'CC017-455' and its infection value is '10250'
# Minimum Score:  279.82681431521735
# After Training Min:  10403
# After Infection Min:  10403
# First anomaly found after training: 3203 minutes with score 268.3197428559478
# First anomaly found after infection: 153 minutes with score 268.3197428559478
# True Positve Rate: 67.35751295336787%
# Found 'CC017-456' and its infection value is '10250'
# Skipping division
# Found 'CC036-299' and its infection value is '10250'
# Minimum Score:  485.5514801986624
# After Training Min:  8908
# After Infection Min:  10342
# First anomaly found after training: 1708 minutes with score 482.73758381779686
# First anomaly found after infection: 92 minutes with score 478.00879963866987
# True Positve Rate: 99.3222757267701%
# No match found for mouse 'B6-100'
# Minimum Score:  413.9642069660991
# After Training Min:  14191
# After Infection Min:  14191
# First anomaly found after training: 6991 minutes with score 334.5413976073311
# First anomaly found after infection: 3941 minutes with score 334.5413976073311
# True Positve Rate: 100.0%
# No match found for mouse 'B6-101'
# Minimum Score:  373.0302825449287
# After Training Min:  16312
# After Infection Min:  16312
# First anomaly found after training: 9112 minutes with score 355.98693047967294
# First anomaly found after infection: 6062 minutes with score 355.98693047967294
# True Positve Rate: 100.0%
# Found 'CC002-557' and its infection value is '14200'
# Minimum Score:  201.79012843331373
# After Training Min:  16325
# After Infection Min:  16325
# First anomaly found after training: 9125 minutes with score 200.16611150736367
# First anomaly found after infection: 2125 minutes with score 200.16611150736367
# True Positve Rate: 100.0%
# Found 'CC002-558' and its infection value is '14200'
# Minimum Score:  325.66180330120756
# After Training Min:  8422
# After Infection Min:  14566
# First anomaly found after training: 1222 minutes with score 160.53621948582975
# First anomaly found after infection: 366 minutes with score 291.16868492608273
# True Positve Rate: 98.92011147236414%
# Found 'CC002-559' and its infection value is '14200'
# Minimum Score:  257.7441911007911
# After Training Min:  8424
# After Infection Min:  14580
# First anomaly found after training: 1224 minutes with score 92.19806872582092
# First anomaly found after infection: 380 minutes with score 253.9266655965505
# True Positve Rate: 10.0%
# Found 'CC015-390' and its infection value is '14200'
# Skipping division
# Found 'CC015-391' and its infection value is '14200'
# Minimum Score:  293.05909362979605
# After Training Min:  19593
# After Infection Min:  19593
# First anomaly found after training: 12393 minutes with score 286.46903321360014
# First anomaly found after infection: 5393 minutes with score 286.46903321360014
# True Positve Rate: 100.0%
# Found 'CC015-392' and its infection value is '14200'
# Minimum Score:  427.3545844719542
# After Training Min:  8629
# After Infection Min:  17365
# First anomaly found after training: 1429 minutes with score 424.4221028955026
# First anomaly found after infection: 3165 minutes with score 411.1302021485993
# True Positve Rate: 10.933940774487471%
# Found 'CC038-582' and its infection value is '14200'
# Minimum Score:  343.8405285795375
# After Training Min:  10845
# After Infection Min:  14241
# First anomaly found after training: 3645 minutes with score 337.00689246790887
# First anomaly found after infection: 41 minutes with score 339.4298112310279
# True Positve Rate: 91.08087679516251%
# Found 'CC038-583' and its infection value is '14200'
# Minimum Score:  295.2674067465249
# After Training Min:  9672
# After Infection Min:  14245
# First anomaly found after training: 2472 minutes with score 288.8325049847385
# First anomaly found after infection: 45 minutes with score 230.1512323030704
# True Positve Rate: 80.58252427184466%
# Found 'CC051-495' and its infection value is '14200'
# Minimum Score:  344.67870721461935
# After Training Min:  9162
# After Infection Min:  14390
# First anomaly found after training: 1962 minutes with score 340.9204075355364
# First anomaly found after infection: 190 minutes with score 339.5358670262797
# True Positve Rate: 79.86852917009038%
# Found 'CC051-496' and its infection value is '14200'
# Minimum Score:  275.20000989613993
# After Training Min:  7957
# After Infection Min:  14225
# First anomaly found after training: 757 minutes with score 272.6237816773411
# First anomaly found after infection: 25 minutes with score 269.61608529926195
# True Positve Rate: 81.14063512637719%
# Found 'CC006-507' and its infection value is '10500'
# Minimum Score:  430.49093148218
# After Training Min:  9925
# After Infection Min:  11392
# First anomaly found after training: 2725 minutes with score 414.40404847297697
# First anomaly found after infection: 892 minutes with score 417.29395105829155
# True Positve Rate: 99.07578558225508%
# Found 'CC006-508' and its infection value is '10500'
# Minimum Score:  474.51735370966145
# After Training Min:  13020
# After Infection Min:  13020
# First anomaly found after training: 5820 minutes with score 472.4586686468039
# First anomaly found after infection: 2520 minutes with score 472.4586686468039
# True Positve Rate: 100.0%
# Found 'CC017-413' and its infection value is '10500'
# Minimum Score:  315.44859327342056
# After Training Min:  17377
# After Infection Min:  17377
# First anomaly found after training: 10177 minutes with score 294.1690444283073
# First anomaly found after infection: 6877 minutes with score 294.1690444283073
# True Positve Rate: 100.0%
# Found 'CC036-276' and its infection value is '10500'
# Minimum Score:  541.6347705873771
# After Training Min:  10499
# After Infection Min:  10500
# First anomaly found after training: 3299 minutes with score 483.58096754483086
# First anomaly found after infection: 0 minutes with score 435.9723124503196
# True Positve Rate: 99.79286319555597%
# Found 'CC036-279' and its infection value is '10500'
# Minimum Score:  427.92554627383925
# After Training Min:  9010
# After Infection Min:  10503
# First anomaly found after training: 1810 minutes with score 427.68335065662
# First anomaly found after infection: 3 minutes with score 394.320993631163
# True Positve Rate: 90.1990811638591%
# No match found for mouse 'CC036-280'
# Minimum Score:  452.5240455708549
# After Training Min:  15559
# After Infection Min:  15559
# First anomaly found after training: 8359 minutes with score 433.7924221555867
# First anomaly found after infection: 5059 minutes with score 433.7924221555867
# True Positve Rate: 100.0%
# Found 'CC036-281' and its infection value is '10500'
# Minimum Score:  432.36576480358235
# After Training Min:  12584
# After Infection Min:  12584
# First anomaly found after training: 5384 minutes with score 391.48077322150397
# First anomaly found after infection: 2084 minutes with score 391.48077322150397
# True Positve Rate: 100.0%
# Found 'CC057-732' and its infection value is '10500'
# Minimum Score:  409.3886179889823
# After Training Min:  9247
# After Infection Min:  12799
# First anomaly found after training: 2047 minutes with score 406.95805395763523
# First anomaly found after infection: 2299 minutes with score 404.5546436919659
# True Positve Rate: 98.71657754010695%
# Found 'CC061-554' and its infection value is '10500'
# Minimum Score:  468.7594901328059
# After Training Min:  8094
# After Infection Min:  10519
# First anomaly found after training: 894 minutes with score 455.5198210848795
# First anomaly found after infection: 19 minutes with score 425.11820637784916
# True Positve Rate: 99.38992321447354%
# Found 'CC061-555' and its infection value is '10500'
# Minimum Score:  208.3754980676424
# After Training Min:  10523
# After Infection Min:  10523
# First anomaly found after training: 3323 minutes with score 198.3468028266533
# First anomaly found after infection: 23 minutes with score 198.3468028266533
# True Positve Rate: 37.5%
# Found 'CC061-556' and its infection value is '10500'
# Minimum Score:  423.41748752712033
# After Training Min:  10403
# After Infection Min:  10520
# First anomaly found after training: 3203 minutes with score 416.6278285724577
# First anomaly found after infection: 20 minutes with score 375.3110252788938
# True Positve Rate: 99.50461389023798%
# Found 'B6-117' and its infection value is '10500'
# Minimum Score:  396.5476628742167
# After Training Min:  10523
# After Infection Min:  10523
# First anomaly found after training: 3323 minutes with score 383.6538401027766
# First anomaly found after infection: 23 minutes with score 383.6538401027766
# True Positve Rate: 71.42857142857143%
# Found 'CC001-304' and its infection value is '11300'
# Minimum Score:  272.2749682906503
# After Training Min:  14023
# After Infection Min:  14023
# First anomaly found after training: 6823 minutes with score 264.52750363144713
# First anomaly found after infection: 2723 minutes with score 264.52750363144713
# True Positve Rate: 100.0%
# No match found for mouse 'CC001-306'
# Minimum Score:  346.7776952383322
# After Training Min:  9874
# After Infection Min:  11300
# First anomaly found after training: 2674 minutes with score 341.2014715330348
# First anomaly found after infection: 0 minutes with score 191.83129877959084
# True Positve Rate: 98.47061980144889%
# Found 'CC013-671' and its infection value is '11300'
# Minimum Score:  333.52563096653375
# After Training Min:  12476
# After Infection Min:  12476
# First anomaly found after training: 5276 minutes with score 331.5791842619535
# First anomaly found after infection: 1176 minutes with score 331.5791842619535
# True Positve Rate: 100.0%
# Found 'CC013-672' and its infection value is '11300'
# Minimum Score:  385.66801169356074
# After Training Min:  13735
# After Infection Min:  13735
# First anomaly found after training: 6535 minutes with score 371.9777153960701
# First anomaly found after infection: 2435 minutes with score 371.9777153960701
# True Positve Rate: 100.0%
# Found 'CC013-673' and its infection value is '11300'
# Minimum Score:  458.53286706730074
# After Training Min:  11757
# After Infection Min:  11757
# First anomaly found after training: 4557 minutes with score 455.1949414546802
# First anomaly found after infection: 457 minutes with score 455.1949414546802
# True Positve Rate: 99.98991325398427%
# Found 'CC015-439' and its infection value is '11300'
# Minimum Score:  396.37401815009116
# After Training Min:  12293
# After Infection Min:  12293
# First anomaly found after training: 5093 minutes with score 396.33621208506963
# First anomaly found after infection: 993 minutes with score 396.33621208506963
# True Positve Rate: 100.0%
# No match found for mouse 'CC015-442'
# Minimum Score:  171.566773713433
# After Training Min:  20972
# After Infection Min:  20972
# First anomaly found after training: 13772 minutes with score 167.00521770431328
# First anomaly found after infection: 9672 minutes with score 167.00521770431328
# True Positve Rate: 100.0%
# No match found for mouse 'CC024-361'
# Minimum Score:  499.34271788238715
# After Training Min:  11318
# After Infection Min:  11318
# First anomaly found after training: 4118 minutes with score 358.37805670872115
# First anomaly found after infection: 18 minutes with score 358.37805670872115
# True Positve Rate: 99.65274604770173%
# Found 'CC024-362' and its infection value is '11300'
# Minimum Score:  251.80354354896497
# After Training Min:  9517
# After Infection Min:  18601
# First anomaly found after training: 2317 minutes with score 249.5231855278438
# First anomaly found after infection: 7301 minutes with score 240.97708190978415
# True Positve Rate: 55.294117647058826%
# Found 'CC025-598' and its infection value is '11300'
# Skipping division
# Found 'CC025-599' and its infection value is '11300'
# Minimum Score:  405.3295159205656
# After Training Min:  11338
# After Infection Min:  11338
# First anomaly found after training: 4138 minutes with score 379.1242863382556
# First anomaly found after infection: 38 minutes with score 379.1242863382556
# True Positve Rate: 75.75757575757575%
# Found 'CC025-600' and its infection value is '11300'
# Minimum Score:  438.072448013056
# After Training Min:  8133
# After Infection Min:  11348
# First anomaly found after training: 933 minutes with score 432.9922399946075
# First anomaly found after infection: 48 minutes with score 413.14689790856977
# True Positve Rate: 90.81632653061224%
# Found 'CC038-659' and its infection value is '11300'
# Minimum Score:  286.5814364458162
# After Training Min:  8166
# After Infection Min:  11345
# First anomaly found after training: 966 minutes with score 276.56093127922696
# First anomaly found after infection: 45 minutes with score 255.1627734355353
# True Positve Rate: 99.35456831517183%
# Found 'CC038-660' and its infection value is '11300'
# Minimum Score:  347.0887524390056
# After Training Min:  9993
# After Infection Min:  11351
# First anomaly found after training: 2793 minutes with score 338.37734972557826
# First anomaly found after infection: 51 minutes with score 334.0706048772163
# True Positve Rate: 21.21212121212121%
# Found 'CC038-661' and its infection value is '11300'
# Minimum Score:  282.6698030760466
# After Training Min:  11355
# After Infection Min:  11355
# First anomaly found after training: 4155 minutes with score 178.18421236860001
# First anomaly found after infection: 55 minutes with score 178.18421236860001
# True Positve Rate: 92.01065246338216%
# Found 'CC015-514' and its infection value is '11500'
# Minimum Score:  339.35831883186097
# After Training Min:  16680
# After Infection Min:  16680
# First anomaly found after training: 9480 minutes with score 323.47435619305134
# First anomaly found after infection: 5180 minutes with score 323.47435619305134
# True Positve Rate: 100.0%
# Found 'CC015-515' and its infection value is '11500'
# Minimum Score:  205.3422329010001
# After Training Min:  13931
# After Infection Min:  13931
# First anomaly found after training: 6731 minutes with score 201.22914211729892
# First anomaly found after infection: 2431 minutes with score 201.22914211729892
# True Positve Rate: 100.0%
# Found 'CC024-409' and its infection value is '11500'
# Minimum Score:  428.9141555359501
# After Training Min:  11040
# After Infection Min:  11500
# First anomaly found after training: 3840 minutes with score 425.041690654315
# First anomaly found after infection: 0 minutes with score 410.96510720483855
# True Positve Rate: 71.95121951219512%
# No match found for mouse 'CC036-271'
# Minimum Score:  574.802914044545
# After Training Min:  8510
# After Infection Min:  13315
# First anomaly found after training: 1310 minutes with score 557.6418915162855
# First anomaly found after infection: 1815 minutes with score 566.913268414313
# True Positve Rate: 97.9560938682816%
# Found 'CC036-272' and its infection value is '11500'
# Minimum Score:  349.1690087963581
# After Training Min:  12546
# After Infection Min:  12546
# First anomaly found after training: 5346 minutes with score 321.24643249233975
# First anomaly found after infection: 1046 minutes with score 321.24643249233975
# True Positve Rate: 100.0%
# Found 'CC053-426' and its infection value is '11500'
# Minimum Score:  369.075156739669
# After Training Min:  10612
# After Infection Min:  14746
# First anomaly found after training: 3412 minutes with score 366.60810557480556
# First anomaly found after infection: 3246 minutes with score 367.95689345588534
# True Positve Rate: 25.53191489361702%
# Found 'CC053-427' and its infection value is '11500'
# Minimum Score:  126.3670086014755
# After Training Min:  12514
# After Infection Min:  12514
# First anomaly found after training: 5314 minutes with score 125.10567505949234
# First anomaly found after infection: 1014 minutes with score 125.10567505949234
# True Positve Rate: 100.0%
# Found 'CC053-428' and its infection value is '11500'
# Minimum Score:  163.65580367257178
# After Training Min:  20286
# After Infection Min:  20286
# First anomaly found after training: 13086 minutes with score 161.84623535350795
# First anomaly found after infection: 8786 minutes with score 161.84623535350795
# True Positve Rate: 100.0%
# Found 'CC057-730' and its infection value is '11500'
# Minimum Score:  355.7710402520893
# After Training Min:  8507
# After Infection Min:  11700
# First anomaly found after training: 1307 minutes with score 339.96482404478775
# First anomaly found after infection: 200 minutes with score 348.6424133538318
# True Positve Rate: 16.867469879518072%
# Found 'CC057-731' and its infection value is '11500'
# Minimum Score:  295.1443639716765
# After Training Min:  10733
# After Infection Min:  11674
# First anomaly found after training: 3533 minutes with score 288.1679598848932
# First anomaly found after infection: 174 minutes with score 280.5572985410438
# True Positve Rate: 98.9967261590453%
# Found 'CC058-296' and its infection value is '11500'
# Minimum Score:  246.49109642866006
# After Training Min:  12779
# After Infection Min:  12779
# First anomaly found after training: 5579 minutes with score 243.91647626170493
# First anomaly found after infection: 1279 minutes with score 243.91647626170493
# True Positve Rate: 100.0%
# Found 'CC058-297' and its infection value is '11500'
# Minimum Score:  198.1916589248574
# After Training Min:  8266
# After Infection Min:  12378
# First anomaly found after training: 1066 minutes with score 195.8154862666645
# First anomaly found after infection: 878 minutes with score 198.04451674567076
# True Positve Rate: 99.99110478562532%
# Found 'CC058-298' and its infection value is '11500'
# Minimum Score:  374.98902110091467
# After Training Min:  9323
# After Infection Min:  11900
# First anomaly found after training: 2123 minutes with score 373.939171811111
# First anomaly found after infection: 400 minutes with score 361.72613985254776
# True Positve Rate: 97.41697416974169%
# No match found for mouse 'CC061-542'
# Skipping division
# Found 'CC061-543' and its infection value is '11500'
# Minimum Score:  143.62532160007515
# After Training Min:  16678
# After Infection Min:  16678
# First anomaly found after training: 9478 minutes with score 135.9963625361728
# First anomaly found after infection: 5178 minutes with score 135.9963625361728
# True Positve Rate: 100.0%
# Found 'CC061-544' and its infection value is '11500'
# Minimum Score:  340.47547475649816
# After Training Min:  11519
# After Infection Min:  11519
# First anomaly found after training: 4319 minutes with score 326.43906089560016
# First anomaly found after infection: 19 minutes with score 326.43906089560016
# True Positve Rate: 96.81818181818181%
# Found 'CC001-290' and its infection value is '14300'
# Minimum Score:  320.576242057875
# After Training Min:  11249
# After Infection Min:  17673
# First anomaly found after training: 4049 minutes with score 319.13340219805934
# First anomaly found after infection: 3373 minutes with score 315.6105760572027
# True Positve Rate: 99.69964959118973%
# Found 'CC001-292' and its infection value is '14300'
# Minimum Score:  366.6525129726986
# After Training Min:  8207
# After Infection Min:  14607
# First anomaly found after training: 1007 minutes with score 358.9764901429006
# First anomaly found after infection: 307 minutes with score 353.8427252477466
# True Positve Rate: 93.0442158837875%
# Found 'CC005-409' and its infection value is '14300'
# Minimum Score:  470.5323755397801
# After Training Min:  12729
# After Infection Min:  14300
# First anomaly found after training: 5529 minutes with score 465.9088071253416
# First anomaly found after infection: 0 minutes with score 752.4150736090321
# True Positve Rate: 0.0%
# Found 'CC005-410' and its infection value is '14300'
# Skipping division
# Found 'CC005-411' and its infection value is '14300'
# Minimum Score:  328.2099562905639
# After Training Min:  14366
# After Infection Min:  14366
# First anomaly found after training: 7166 minutes with score 307.33378234042004
# First anomaly found after infection: 66 minutes with score 307.33378234042004
# True Positve Rate: 91.77215189873418%
# Found 'CC019-1445' and its infection value is '14300'
# Minimum Score:  137.15096832090637
# After Training Min:  22369
# After Infection Min:  22369
# First anomaly found after training: 15169 minutes with score 123.49270502645447
# First anomaly found after infection: 8069 minutes with score 123.49270502645447
# True Positve Rate: 100.0%
# Found 'CC019-1451' and its infection value is '14300'
# Minimum Score:  260.8588647785094
# After Training Min:  14345
# After Infection Min:  14345
# First anomaly found after training: 7145 minutes with score 196.0625482599346
# First anomaly found after infection: 45 minutes with score 196.0625482599346
# True Positve Rate: 94.33962264150944%
# Found 'CC019-1452' and its infection value is '14300'
# Minimum Score:  163.18121214825055
# After Training Min:  14348
# After Infection Min:  14348
# First anomaly found after training: 7148 minutes with score 106.88059091409218
# First anomaly found after infection: 48 minutes with score 106.88059091409218
# True Positve Rate: 34.04255319148936%
# Found 'CC023-567' and its infection value is '14300'
# Minimum Score:  297.0389003272187
# After Training Min:  8096
# After Infection Min:  14365
# First anomaly found after training: 896 minutes with score 254.81954845290898
# First anomaly found after infection: 65 minutes with score 200.4392117792878
# True Positve Rate: 56.12244897959183%
# Found 'CC023-568' and its infection value is '14300'
# Minimum Score:  231.68919121370948
# After Training Min:  10343
# After Infection Min:  14367
# First anomaly found after training: 3143 minutes with score 226.0266620761695
# First anomaly found after infection: 67 minutes with score 135.09130682582065
# True Positve Rate: 66.32124352331607%
# Found 'CC023-569' and its infection value is '14300'
# Minimum Score:  246.5245007405407
# After Training Min:  14369
# After Infection Min:  14369
# First anomaly found after training: 7169 minutes with score 240.41734840703725
# First anomaly found after infection: 69 minutes with score 240.41734840703725
# True Positve Rate: 30.952380952380953%
# Found 'CC023-571' and its infection value is '14300'
# Minimum Score:  284.50760033411115
# After Training Min:  15692
# After Infection Min:  15692
# First anomaly found after training: 8492 minutes with score 269.6221616481069
# First anomaly found after infection: 1392 minutes with score 269.6221616481069
# True Positve Rate: 100.0%
# Found 'CC023-572' and its infection value is '14300'
# Minimum Score:  449.4293122091446
# After Training Min:  10930
# After Infection Min:  15860
# First anomaly found after training: 3730 minutes with score 448.7281354905536
# First anomaly found after infection: 1560 minutes with score 369.5859134125876
# True Positve Rate: 73.13432835820896%
# Found 'CC023-577' and its infection value is '14300'
# Minimum Score:  285.2124108175178
# After Training Min:  14383
# After Infection Min:  14383
# First anomaly found after training: 7183 minutes with score 282.6403625076117
# First anomaly found after infection: 83 minutes with score 282.6403625076117
# True Positve Rate: 45.78313253012048%
# No match found for mouse 'CC023-578'
# Minimum Score:  208.0113234494454
# After Training Min:  17106
# After Infection Min:  17106
# First anomaly found after training: 9906 minutes with score 129.88417013006585
# First anomaly found after infection: 2806 minutes with score 129.88417013006585
# True Positve Rate: 100.0%
# No match found for mouse 'B6-102'
# Minimum Score:  438.0114985304427
# After Training Min:  11933
# After Infection Min:  23084
# First anomaly found after training: 4733 minutes with score 437.93422751911737
# First anomaly found after infection: 8784 minutes with score 428.73955599492695
# True Positve Rate: 97.45762711864407%
# No match found for mouse 'CC003-184'
# Minimum Score:  328.5245161994507
# After Training Min:  10261
# After Infection Min:  14300
# First anomaly found after training: 3061 minutes with score 207.46589670146238
# First anomaly found after infection: 0 minutes with score 0.0
# True Positve Rate: 71.29918337045285%
# Found 'CC003-187' and its infection value is '10250'
# Minimum Score:  312.28082574951287
# After Training Min:  10264
# After Infection Min:  10264
# First anomaly found after training: 3064 minutes with score 273.21579262339753
# First anomaly found after infection: 14 minutes with score 273.21579262339753
# True Positve Rate: 35.13513513513514%
# Found 'CC003-190' and its infection value is '10250'
# Minimum Score:  386.09435909004634
# After Training Min:  9257
# After Infection Min:  10265
# First anomaly found after training: 2057 minutes with score 339.5908985171586
# First anomaly found after infection: 15 minutes with score 352.99765000973184
# True Positve Rate: 81.37254901960785%
# Found 'CC012-1348' and its infection value is '10250'
# Minimum Score:  465.90628394319384
# After Training Min:  8900
# After Infection Min:  10278
# First anomaly found after training: 1700 minutes with score 464.95888357554696
# First anomaly found after infection: 28 minutes with score 430.02566382666566
# True Positve Rate: 97.80077619663649%
# Found 'CC012-1349' and its infection value is '10250'
# Minimum Score:  428.5326129635543
# After Training Min:  8556
# After Infection Min:  10279
# First anomaly found after training: 1356 minutes with score 392.23149794045247
# First anomaly found after infection: 29 minutes with score 399.3692947937278
# True Positve Rate: 92.25531914893617%
# Found 'CC012-1350' and its infection value is '10250'
# Minimum Score:  287.1920057810662
# After Training Min:  10288
# After Infection Min:  10288
# First anomaly found after training: 3088 minutes with score 284.1193915391408
# First anomaly found after infection: 38 minutes with score 284.1193915391408
# True Positve Rate: 83.05084745762711%
# Found 'CC012-1354' and its infection value is '10250'
# Minimum Score:  235.84768981217633
# After Training Min:  8550
# After Infection Min:  10282
# First anomaly found after training: 1350 minutes with score 223.94733150028867
# First anomaly found after infection: 32 minutes with score 183.399496568083
# True Positve Rate: 66.33663366336634%
# Found 'CC012-1357' and its infection value is '10250'
# Minimum Score:  159.6917443218315
# After Training Min:  9065
# After Infection Min:  10572
# First anomaly found after training: 1865 minutes with score 154.301657670321
# First anomaly found after infection: 322 minutes with score 158.3397916761479
# True Positve Rate: 0.0%
# Found 'CC012-1359' and its infection value is '10250'
# Minimum Score:  111.66862095303838
# After Training Min:  8355
# After Infection Min:  13620
# First anomaly found after training: 1155 minutes with score 110.46033902359352
# First anomaly found after infection: 3370 minutes with score 107.86019154901999
# True Positve Rate: 28.000000000000004%
# Found 'CC025-620' and its infection value is '10250'
# Minimum Score:  485.8687665088326
# After Training Min:  13883
# After Infection Min:  13883
# First anomaly found after training: 6683 minutes with score 473.12015941744875
# First anomaly found after infection: 3633 minutes with score 473.12015941744875
# True Positve Rate: 100.0%
# Found 'CC037-488' and its infection value is '10250'
# Minimum Score:  557.589656266598
# After Training Min:  8562
# After Infection Min:  11145
# First anomaly found after training: 1362 minutes with score 226.44116571661073
# First anomaly found after infection: 895 minutes with score 550.2804969628571
# True Positve Rate: 99.32013006207508%
# Found 'CC037-489' and its infection value is '10250'
# Minimum Score:  416.1433148525095
# After Training Min:  8593
# After Infection Min:  10701
# First anomaly found after training: 1393 minutes with score 186.86422918427309
# First anomaly found after infection: 451 minutes with score 406.39905683959176
# True Positve Rate: 96.26474442988204%
# Found 'CC037-490' and its infection value is '10250'
# Minimum Score:  294.66623028560025
# After Training Min:  8571
# After Infection Min:  11371
# First anomaly found after training: 1371 minutes with score 204.94179141932045
# First anomaly found after infection: 1121 minutes with score 289.6326447915967
# True Positve Rate: 98.7091222030981%
# Found 'CC037-491' and its infection value is '10250'
# Minimum Score:  417.8548469956338
# After Training Min:  8573
# After Infection Min:  11363
# First anomaly found after training: 1373 minutes with score 408.21981262004147
# First anomaly found after infection: 1113 minutes with score 401.23166733724116
# True Positve Rate: 99.75460122699387%
# Found 'CC037-492' and its infection value is '10250'
# Minimum Score:  400.99620452743704
# After Training Min:  8219
# After Infection Min:  10252
# First anomaly found after training: 1019 minutes with score 394.3546231490503
# First anomaly found after infection: 2 minutes with score 395.3004630910759
# True Positve Rate: 99.30516165626773%
# Found 'CC037-493' and its infection value is '10250'
# Minimum Score:  446.3567140045065
# After Training Min:  10320
# After Infection Min:  10320
# First anomaly found after training: 3120 minutes with score 383.42684062694303
# First anomaly found after infection: 70 minutes with score 383.42684062694303
# True Positve Rate: 99.73809134064496%
# No match found for mouse 'C57Bl6-104'
# Minimum Score:  434.9637549298852
# After Training Min:  9522
# After Infection Min:  11563
# First anomaly found after training: 2322 minutes with score 429.38767673671276
# First anomaly found after infection: 1313 minutes with score 418.4561285680206
# True Positve Rate: 99.9315537303217%
# Found 'C57Bl6-105' and its infection value is '10000'
# Minimum Score:  370.8982472319519
# After Training Min:  9119
# After Infection Min:  11456
# First anomaly found after training: 1919 minutes with score 351.1156402335935
# First anomaly found after infection: 1456 minutes with score 368.7268228002352
# True Positve Rate: 99.63963963963964%
# Found 'C57Bl6-106' and its infection value is '10000'
# Minimum Score:  403.043046757753
# After Training Min:  8808
# After Infection Min:  12019
# First anomaly found after training: 1608 minutes with score 386.72065114383776
# First anomaly found after infection: 2019 minutes with score 386.377591478678
# True Positve Rate: 88.65979381443299%
# Found 'CC019-1513' and its infection value is '10000'
# Minimum Score:  204.7639683094095
# After Training Min:  10046
# After Infection Min:  10046
# First anomaly found after training: 2846 minutes with score 170.67558631406064
# First anomaly found after infection: 46 minutes with score 170.67558631406064
# True Positve Rate: 31.57894736842105%
# Found 'CC019-1514' and its infection value is '10000'
# Skipping division
# Found 'CC024-363' and its infection value is '10000'
# Minimum Score:  370.5210895921715
# After Training Min:  8915
# After Infection Min:  10055
# First anomaly found after training: 1715 minutes with score 360.08783479554506
# First anomaly found after infection: 55 minutes with score 235.77611753711142
# True Positve Rate: 99.1193306913254%
# Found 'CC024-364' and its infection value is '10000'
# Minimum Score:  514.0594250712094
# After Training Min:  10059
# After Infection Min:  10059
# First anomaly found after training: 2859 minutes with score 413.54636161946524
# First anomaly found after infection: 59 minutes with score 413.54636161946524
# True Positve Rate: 26.5625%
# Found 'CC024-365' and its infection value is '10000'
# Minimum Score:  396.7457636690304
# After Training Min:  10072
# After Infection Min:  10072
# First anomaly found after training: 2872 minutes with score 342.4509166918177
# First anomaly found after infection: 72 minutes with score 342.4509166918177
# True Positve Rate: 41.17647058823529%
# Found 'CC025-603' and its infection value is '10000'
# Minimum Score:  392.9807553098379
# After Training Min:  8062
# After Infection Min:  12791
# First anomaly found after training: 862 minutes with score 382.87013035162687
# First anomaly found after infection: 2791 minutes with score 390.00303780404676
# True Positve Rate: 47.61904761904761%
# Found 'CC027-392' and its infection value is '10000'
# Minimum Score:  220.58217924929784
# After Training Min:  12174
# After Infection Min:  12174
# First anomaly found after training: 4974 minutes with score 218.894985018086
# First anomaly found after infection: 2174 minutes with score 218.894985018086
# True Positve Rate: 100.0%
# Found 'CC027-393' and its infection value is '10000'
# Minimum Score:  382.14532112203483
# After Training Min:  11423
# After Infection Min:  11423
# First anomaly found after training: 4223 minutes with score 354.7629565084094
# First anomaly found after infection: 1423 minutes with score 354.7629565084094
# True Positve Rate: 100.0%
# Found 'CC042-330' and its infection value is '10000'
# Minimum Score:  116.45294017798699
# After Training Min:  11048
# After Infection Min:  11048
# First anomaly found after training: 3848 minutes with score 107.79937443677068
# First anomaly found after infection: 1048 minutes with score 107.79937443677068
# True Positve Rate: 100.0%
# Found 'CC042-331' and its infection value is '10000'
# Minimum Score:  195.29973347235625
# After Training Min:  9911
# After Infection Min:  10278
# First anomaly found after training: 2711 minutes with score 172.8886902254245
# First anomaly found after infection: 278 minutes with score 184.0978828607291
# True Positve Rate: 91.48936170212765%
# Found 'CC042-332' and its infection value is '10000'
# Minimum Score:  62.936666620394135
# After Training Min:  10484
# After Infection Min:  10484
# First anomaly found after training: 3284 minutes with score 62.01140850188449
# First anomaly found after infection: 484 minutes with score 62.01140850188449
# True Positve Rate: 92.7710843373494%
# Found 'CC006-510' and its infection value is '10500'
# Minimum Score:  169.34074709618187
# After Training Min:  16941
# After Infection Min:  16941
# First anomaly found after training: 9741 minutes with score 161.81142431923843
# First anomaly found after infection: 6441 minutes with score 161.81142431923843
# True Positve Rate: 100.0%
# Found 'CC017-426' and its infection value is '10500'
# Skipping division
# Found 'CC036-290' and its infection value is '10500'
# Minimum Score:  453.6364387231719
# After Training Min:  11410
# After Infection Min:  11410
# First anomaly found after training: 4210 minutes with score 441.69968309485665
# First anomaly found after infection: 910 minutes with score 441.69968309485665
# True Positve Rate: 100.0%
# Found 'CC043-607' and its infection value is '10500'
# Minimum Score:  196.39933134202136
# After Training Min:  10453
# After Infection Min:  10500
# First anomaly found after training: 3253 minutes with score 165.4746223192966
# First anomaly found after infection: 0 minutes with score 874.3576064902314
# True Positve Rate: 0.0%
# Found 'CC058-317' and its infection value is '10500'
# Minimum Score:  450.5336967516257
# After Training Min:  8566
# After Infection Min:  12808
# First anomaly found after training: 1366 minutes with score 433.0081211060845
# First anomaly found after infection: 2308 minutes with score 447.2108789241508
# True Positve Rate: 98.8035892323031%
# Found 'CC058-318' and its infection value is '10500'
# Minimum Score:  406.0069760038355
# After Training Min:  11364
# After Infection Min:  11364
# First anomaly found after training: 4164 minutes with score 399.7986408127184
# First anomaly found after infection: 864 minutes with score 399.7986408127184
# True Positve Rate: 100.0%
# Found 'CC058-319' and its infection value is '10500'
# Minimum Score:  360.0248619261817
# After Training Min:  8588
# After Infection Min:  12080
# First anomaly found after training: 1388 minutes with score 355.12927579729103
# First anomaly found after infection: 1580 minutes with score 355.1346104080545
# True Positve Rate: 99.34906427990235%
# Found 'CC061-565' and its infection value is '10500'
# Minimum Score:  354.6734871023189
# After Training Min:  8893
# After Infection Min:  12584
# First anomaly found after training: 1693 minutes with score 344.5153959061798
# First anomaly found after infection: 2084 minutes with score 343.0581807490386
# True Positve Rate: 80.0%
# Found 'CC001-325' and its infection value is '10100'
# Minimum Score:  236.90634548180788
# After Training Min:  12388
# After Infection Min:  12388
# First anomaly found after training: 5188 minutes with score 228.95474576215304
# First anomaly found after infection: 2288 minutes with score 228.95474576215304
# True Positve Rate: 100.0%
# Found 'CC025-645' and its infection value is '10100'
# Minimum Score:  326.5371872236476
# After Training Min:  10121
# After Infection Min:  10121
# First anomaly found after training: 2921 minutes with score 244.80183601910676
# First anomaly found after infection: 21 minutes with score 244.80183601910676
# True Positve Rate: 95.34109816971714%
# Found 'CC027-426' and its infection value is '10100'
# Minimum Score:  337.61752448431537
# After Training Min:  10124
# After Infection Min:  10124
# First anomaly found after training: 2924 minutes with score 235.04105045714505
# First anomaly found after infection: 24 minutes with score 235.04105045714505
# True Positve Rate: 99.90777460112515%
# Found 'CC038-669' and its infection value is '10100'
# Minimum Score:  311.62160657766384
# After Training Min:  10132
# After Infection Min:  10132
# First anomaly found after training: 2932 minutes with score 279.3158589740489
# First anomaly found after infection: 32 minutes with score 279.3158589740489
# True Positve Rate: 26.666666666666668%
# Found 'CC042-347' and its infection value is '10100'
# Minimum Score:  25.790482055170628
# After Training Min:  13328
# After Infection Min:  13328
# First anomaly found after training: 6128 minutes with score 20.315429223276396
# First anomaly found after infection: 3228 minutes with score 20.315429223276396
# True Positve Rate: 100.0%
# Found 'CC042-348' and its infection value is '10100'
# Minimum Score:  215.70233883858816
# After Training Min:  11152
# After Infection Min:  11152
# First anomaly found after training: 3952 minutes with score 208.8902715974441
# First anomaly found after infection: 1052 minutes with score 208.8902715974441
# True Positve Rate: 100.0%
# Found 'CC042-349' and its infection value is '10100'
# Minimum Score:  284.3444231108666
# After Training Min:  19811
# After Infection Min:  19811
# First anomaly found after training: 12611 minutes with score 278.4711119451879
# First anomaly found after infection: 9711 minutes with score 278.4711119451879
# True Positve Rate: 100.0%
# Found 'CC043-562' and its infection value is '10100'
# Minimum Score:  286.10855955127465
# After Training Min:  10139
# After Infection Min:  10139
# First anomaly found after training: 2939 minutes with score 283.07953638570507
# First anomaly found after infection: 39 minutes with score 283.07953638570507
# True Positve Rate: 0.0%
# No match found for mouse 'CC043-563'
# Minimum Score:  274.19628098587
# After Training Min:  12910
# After Infection Min:  12910
# First anomaly found after training: 5710 minutes with score 226.96188986771915
# First anomaly found after infection: 2810 minutes with score 226.96188986771915
# True Positve Rate: 100.0%
# Found 'CC043-564' and its infection value is '10100'
# Minimum Score:  271.3127066764117
# After Training Min:  8266
# After Infection Min:  10100
# First anomaly found after training: 1066 minutes with score 263.15240216852465
# First anomaly found after infection: 0 minutes with score 739.0486282922167
# True Positve Rate: 0.0%
# Found 'CC051-615' and its infection value is '10100'
# Minimum Score:  288.1981617498287
# After Training Min:  9891
# After Infection Min:  10247
# First anomaly found after training: 2691 minutes with score 253.6155136965765
# First anomaly found after infection: 147 minutes with score 281.3137722459974
# True Positve Rate: 97.98464491362763%
# Found 'CC053-366' and its infection value is '10100'
# Skipping division
# Found 'CC053-370' and its infection value is '10100'
# Minimum Score:  239.75382156155808
# After Training Min:  12344
# After Infection Min:  12344
# First anomaly found after training: 5144 minutes with score 232.780557250347
# First anomaly found after infection: 2244 minutes with score 232.780557250347
# True Positve Rate: 100.0%
# Found 'CC053-371' and its infection value is '10100'
# Skipping division
# Found 'CC057-704' and its infection value is '10100'
# Skipping division
# Found 'CC057-705' and its infection value is '10100'
# Minimum Score:  277.83030018335205
# After Training Min:  14138
# After Infection Min:  14138
# First anomaly found after training: 6938 minutes with score 267.0522838395874
# First anomaly found after infection: 4038 minutes with score 267.0522838395874
# True Positve Rate: 100.0%
# Found 'C57Bl6-108' and its infection value is '10200'
# Minimum Score:  398.70710631237864
# After Training Min:  12837
# After Infection Min:  12837
# First anomaly found after training: 5637 minutes with score 370.9663618805315
# First anomaly found after infection: 2637 minutes with score 370.9663618805315
# True Positve Rate: 100.0%
# Found 'CC017-394' and its infection value is '10200'
# Minimum Score:  411.1023444914486
# After Training Min:  14234
# After Infection Min:  14234
# First anomaly found after training: 7034 minutes with score 372.3302938172581
# First anomaly found after infection: 4034 minutes with score 372.3302938172581
# True Positve Rate: 100.0%
# Found 'CC017-395' and its infection value is '10200'
# Minimum Score:  410.42083658932114
# After Training Min:  18787
# After Infection Min:  18787
# First anomaly found after training: 11587 minutes with score 409.0308739299402
# First anomaly found after infection: 8587 minutes with score 409.0308739299402
# True Positve Rate: 100.0%
# Found 'CC024-371' and its infection value is '10200'
# Minimum Score:  339.1470868674187
# After Training Min:  8370
# After Infection Min:  10218
# First anomaly found after training: 1170 minutes with score 325.97224885598496
# First anomaly found after infection: 18 minutes with score 228.01629603486185
# True Positve Rate: 55.319148936170215%
# Found 'CC027-400' and its infection value is '10200'
# Minimum Score:  422.19253715772663
# After Training Min:  10221
# After Infection Min:  10221
# First anomaly found after training: 3021 minutes with score 420.09227795632074
# First anomaly found after infection: 21 minutes with score 420.09227795632074
# True Positve Rate: 99.95405678581274%
# Found 'CC027-401' and its infection value is '10200'
# Minimum Score:  315.357340240054
# After Training Min:  12679
# After Infection Min:  12679
# First anomaly found after training: 5479 minutes with score 310.7150837504688
# First anomaly found after infection: 2479 minutes with score 310.7150837504688
# True Positve Rate: 100.0%
# Found 'CC027-403' and its infection value is '10200'
# Minimum Score:  387.7449835006164
# After Training Min:  11404
# After Infection Min:  11404
# First anomaly found after training: 4204 minutes with score 385.3103786183817
# First anomaly found after infection: 1204 minutes with score 385.3103786183817
# True Positve Rate: 100.0%
# Found 'CC041-1752' and its infection value is '10200'
# Minimum Score:  365.3366751089544
# After Training Min:  10464
# After Infection Min:  10464
# First anomaly found after training: 3264 minutes with score 345.2368334852764
# First anomaly found after infection: 264 minutes with score 345.2368334852764
# True Positve Rate: 74.47129909365559%
# Found 'CC041-1753' and its infection value is '10200'
# Minimum Score:  342.78137555822093
# After Training Min:  10977
# After Infection Min:  10977
# First anomaly found after training: 3777 minutes with score 323.51714530024367
# First anomaly found after infection: 777 minutes with score 323.51714530024367
# True Positve Rate: 100.0%
# Found 'CC041-1754' and its infection value is '10200'
# Minimum Score:  341.2676424632947
# After Training Min:  10496
# After Infection Min:  10496
# First anomaly found after training: 3296 minutes with score 335.8697612349554
# First anomaly found after infection: 296 minutes with score 335.8697612349554
# True Positve Rate: 96.90721649484536%
# Found 'CC041-1758' and its infection value is '10200'
# Minimum Score:  348.0335143907552
# After Training Min:  11494
# After Infection Min:  11494
# First anomaly found after training: 4294 minutes with score 341.0298403062397
# First anomaly found after infection: 1294 minutes with score 341.0298403062397
# True Positve Rate: 100.0%
# Found 'CC041-1759' and its infection value is '10200'
# Skipping division
# Found 'CC041-1760' and its infection value is '10200'
# Minimum Score:  267.5291102233756
# After Training Min:  11158
# After Infection Min:  11158
# First anomaly found after training: 3958 minutes with score 265.87774613886415
# First anomaly found after infection: 958 minutes with score 265.87774613886415
# True Positve Rate: 100.0%

# %%
# Make all lists into arrays
ms = np.array(min_scores)
fat = np.array(first_anom_train)
fai = np.array(first_anom_inf)
st = np.array(score_train)
si = np.array(score_infec)
tprs = np.array(tpr)

# %%
# Create the data for the table (calculates statistics)
data = {
    'column_1': [round(np.mean(ms),2), round(np.mean(fat),2), round(np.mean(fai),2), round(np.mean(st),2), round(np.mean(si),2), round(np.mean(tprs)*100,2)],
    'column_2': [round(np.std(ms),2), round(np.std(fat),2), round(np.std(fai),2), round(np.std(st),2), round(np.std(si),2), round(np.std(tprs)*100,2)],
    'column_3': [round(np.percentile(ms, 25),2), round(np.percentile(fat, 25),2), round(np.percentile(fai, 25),2), round(np.percentile(st, 25),2), round(np.percentile(si, 25),2), round(np.percentile(tprs, 25)*100,2)],
    'column_4': [round(np.percentile(ms, 50),2), round(np.percentile(fat, 50),2), round(np.percentile(fai, 50),2), round(np.percentile(st, 50),2), round(np.percentile(si, 50),2), round(np.percentile(tprs, 50)*100,2)],
    'column_5': [round(np.percentile(ms, 75),2), round(np.percentile(fat, 75),2), round(np.percentile(fai, 75),2), round(np.percentile(st, 75),2), round(np.percentile(si, 75),2), round(np.percentile(tprs, 75)*100,2)]
}

# %%
# Create a DataFrame
df = pd.DataFrame(data)

# Set row names (index)
row_names = ['Minimum Score', 'First Anomaly Time After Training', 'First Anomaly Time After Infection', 'First Anomaly Score After Training', 'First Anomaly Score After Infection  ', 'True Positive Rate']
df.index = row_names

# Set column names
column_names = ['Mean', 'Standard Deviation', 'Quartile 1 (25%)', 'Quartile 2 (Med)', 'Quartile 3 (75%)']
df.columns = column_names

# %%
# Saving the Table
# Create a table visualization using matplotlib
fig, ax = plt.subplots(figsize=(6, 4))
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, rowLabels=df.index, loc='center')
table.auto_set_font_size(False)
table.set_fontsize(14)
table.scale(2.5, 2)  # Adjust the scaling factor as per your requirements

# Modify the column names as dark color boxes
for i, col_name in enumerate(df.columns):
    cell = table[0, i]
    cell.set_text_props(weight='bold', color='white')
    cell.set_facecolor('darkgray')
    
# Save the table as an image file
plt.savefig('table_statistics_5days.png', bbox_inches='tight', facecolor='white')

# %%
#fig,ax = plt.subplots(2,1,figsize=(15,10), sharex = False)
#fig.set_facecolor("white")

train_end = 7200 #(5 days)
shift = 2*360 # since the period is 6 hours (360) and we do this twice

# LISTS
# First anomalies after infection
min_scores = []
first_anom_train = []
first_anom_inf = []
score_train = []
score_infec = []
tpr = []
mice = "CC002-558 Exp. 1 MRSA Deg. C Data"

for i in range(0, df_temp.shape[1]): #df_temp.shape[1]
    #ax[0].cla()  # clear axis 0-1
    #ax[1].cla()
    
    #mice_min = range(0, df_temp.shape[0]) # Get the specific minutes for the current temperature time series
    
    temp_value = df_temp.iloc[:, i] # extract the temperature values for the current column
    mice_temp = df_temp.iloc[:, i].to_frame() # converting temp list to data frame
    
    names = mice_temp.columns[0] # get the column name for the current file
    
    # Filing in missing data
    temp_value_fw = temp_value.fillna(method='ffill') # foward fill
    temp_value_bw = temp_value_fw.fillna(method='bfill') # backward fill after forward fill
    
    # Time Delay Embedding
    temp_tde = tde.tde(temp_value_bw) # using the tde file
    temp_tde = temp_tde.T # transporting the data
    
    ##################################################################
    # Fit the Data on the first 5 days (5*24*60) 
    model.fit(temp_tde[:train_end+1,:])
    
    # Predict the Data
    predict_train_data = model.predict(temp_tde[:train_end+1,:]) # predict on training data
    predict_test_data = model.predict(temp_tde[train_end+1:,:]) # predicting on test data
    
    # Scores
    scores_train_data = model.score_samples(temp_tde[:train_end+1,:]) # scores on training data 
    scores_test_data = model.score_samples(temp_tde[train_end+1:,:]) # scores on test data
    
    threshold = model.offset_
    
    ##################################################################
    # Combine training and testing scores and predictions
    combined_scores= np.concatenate((scores_train_data, scores_test_data), axis=0)
    combined_predictions = np.concatenate((predict_train_data, predict_test_data), axis=0)
    
    time = np.arange(temp_tde.shape[0])+(shift) # 2 times the time delay shift
    
    # Minimum score
    min_score = scores_train_data.min()
    
    # Find the indices of the anomalies
    anomaly_indices = np.where(combined_scores <= min_score)[0] #finding the values where its -1 (anomaly)
    time_2 = anomaly_indices + (shift) # shifting the time for plotting
    '''
    ##################################################################
    # Plotting 1st Graph
    ax[0].plot(time, combined_scores, '-', color='#6693F5', alpha=0.75)  # Plot the scores with blue color #[:100]
    ax[0].grid()
    ax[0].set_ylabel("Score", fontsize=14)
    ax[0].set_title(f"Anomalies found using SckiKit Learn's threshold for '{names}'", fontsize=14)
    ax[0].set_xlim(-10,26000)
    ax[0].set_ylim(0,700)
    ax[0].axhline(y = threshold, color='red', linestyle='-', label='threshold')
    # Plot the anomalies with red color
    #ax[0].plot(time_2, combined_scores[anomaly_indices], '', color='purple') #[:100]
    #ax[0].axhline(y=min_score, color='red', linestyle='-')
    '''
    ##################################################################
    # Plotting infection time
    matching_columns = set(mice_temp.columns).intersection(infection_data.columns)
    
    if matching_columns:
        column_name = matching_columns.pop()
        infection_time = infection_data.loc['Aprprox Infection Minute', column_name]
        # Add a vertical line at the infection time
        #ax[1].axvline(x = infection_time, color='purple', linestyle='-', label='Infection time')
        print(f"Found '{column_name}' and its infection value is '{infection_time}'")
    else:
        print(f"No match found for mouse '{names}'")
    
    ##################################################################
    # Find the index at which the first score is less than min_score
    boolean = combined_scores < min_score
    anom_train = np.argmax(boolean) #+shift
    anom_infec = np.argmax(boolean[infection_time-shift:]) + infection_time 
    
    # Get the corresponding value
    value = combined_scores[anom_train]
    value_1 = combined_scores[anom_infec-shift]
    
    # Calculating the time first anomaly was found after training and infection
    time_aft_train = (anom_train + shift) - train_end
    time_aft_infection = anom_infec - infection_time
    
    # Calculating the amount of false negatives (between end of train and infection time)
    count_false_neg = np.count_nonzero(boolean[train_end:infection_time])
    
    # Calculating the amount of true positives (infection time)
    count_true_pos = np.count_nonzero(boolean[infection_time:]) 
    
    # Calculating true positive rate
    # Check if the denominator is zero
    if (count_true_pos + count_false_neg) == 0:
        print("Skipping division ")
        continue  # Skip this iteration and move to the next number
        
    TPR = count_true_pos / (count_true_pos + count_false_neg)
    '''
    ##################################################################
    # Plotting 2nd Graph
    ax[1].plot(time, combined_scores, '-', color='#6693F5', alpha=0.75)  # Plot the scores with blue color #[:100]
    ax[1].plot(time_2, combined_scores[anomaly_indices], '', color='purple') #coloring anomalies
    ax[1].grid()
    ax[1].set_ylabel("Score", fontsize=14)
    ax[1].set_xlabel("Minutes", fontsize=14)
    ax[1].set_title(f"Anomalies found using our threshold for '{names}'", fontsize=14)
    #ax[1].set_xlim(infection_time-5,infection_time+30)
    ax[1].set_xlim(-10,26000)
    ax[1].set_ylim(0,700)
    
    ##################################################################
    # Plotting Horizontal and Vertical Lines
    ax[1].axvline(x = anom_train+shift, color='blue', linestyle='--', label='First anomaly after training') # when the first value is less the minimum value
    ax[1].axvline(x = train_end, color='green', linestyle='-', label='End of training data')
    ax[1].axhline(y=min_score, color='red', linestyle='-', label='Threshold')
    ax[1].axvline(x = anom_infec, color='orange', linestyle ='-', label='First anomaly after infection')
    #ax[1].axhline(y=value, color='blue', linestyle='--', label='value')
    #ax[1].axhline(y=value_1, color='orange', linestyle='-', label='value_1')
    ax[1].legend()
    '''
    ##################################################################
    # Print Values
    print("Minimum Score: ", min_score)
    print("After Training Min: ", anom_train+shift)
    print("After Infection Min: ", anom_infec)
    print(f"First anomaly found after training: {time_aft_train} minutes with score {value}")
    print(f"First anomaly found after infection: {time_aft_infection} minutes with score {value_1}")
    print(f"True Positve Rate: {TPR*100}%")
    
    ##################################################################
    # Appending to Lists
    min_scores.append(min_score)
    first_anom_train.append(time_aft_train)
    first_anom_inf.append(time_aft_infection)
    score_train.append(value)
    score_infec.append(value_1)
    tpr.append(TPR)
# Out:
#   File "<ipython-input-3-169ab1191f7a>", line 17
#     for df_temp[mice]; #i in range(0, df_temp.shape[1]): #df_temp.shape[1]
#                      ^
# SyntaxError: invalid syntax
